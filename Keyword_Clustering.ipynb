# %% [markdown]
# # Download and import librairies

# %%
# Import Librairies
# !pip install gspread_dataframe gspread oauth2client
# !pip install gspread-pandas
# !{sys.executable} -m pip install pygsheets
from gspread_pandas import Spread, Client
from google.oauth2.service_account import Credentials
import pandas as pd
import re
import sys
import json
import gspread
import pygsheets
import csv
from gspread_dataframe import get_as_dataframe, set_with_dataframe
from oauth2client.service_account import ServiceAccountCredentials
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction import text
from sklearn.cluster import DBSCAN

# %% [markdown]
# # Import our Google Search Console data from a CSV file

# %%
# Import our Google Search Console CSV Data into a Dataframe
df = pd.read_csv('Queries.csv', delimiter=',')
df.head(20)
# Out:
#                                   Top queries  Clicks  Impressions     CTR  \
# 0                              adelphi living     255          765  33.33%
# 1                                     adelphi      15          314   4.78%
# 2                         sil providers perth      11           98  11.22%
# 3          supported independent living perth       8          327   2.45%
# 4              disability accommodation perth       4          645   0.62%
# 5                         sda providers perth       4           39  10.26%
# 6                      ndis providers near me       3           54   5.56%
# 7                     adelphi living mandurah       3           18  16.67%
# 8                                    sil ndis       2          906   0.22%
# 9                          ndis housing perth       2          454   0.44%
# 10                       ndis providers perth       2          357   0.56%
# 11   disability supported accommodation perth       2          222    0.9%
# 12                    sil accommodation perth       2           13  15.38%
# 13                                       ndis       1          974    0.1%
# 14                   disability housing perth       1          498    0.2%
# 15  specialist disability accommodation perth       1          434   0.23%
# 16                                        sil       1          342   0.29%
# 17                          ndis events perth       1          264   0.38%
# 18              ndis short term accommodation       1          261   0.38%
# 19         disability service providers perth       1          223   0.45%
#
#     Position
# 0       1.06
# 1      10.04
# 2       2.20
# 3       8.10
# 4      21.36
# 5       7.21
# 6       1.00
# 7       1.06
# 8      37.77
# 9      10.86
# 10     48.13
# 11     13.06
# 12      4.38
# 13      3.13
# 14     24.32
# 15      8.61
# 16      5.02
# 17     15.02
# 18     29.24
# 19     66.67

# %% [markdown]
# ## Create a list of keywords from our GSC data

# %%
# Define a variable to hold our 'Top queries' column only
top_queries = df['Top queries']

# Create a list of keywords and populate it from our dataframe
keywords = []

for x in top_queries:
  keywords.append(x)

# Display keywords list
keywords
# Out:
# ['adelphi living',
#  'adelphi',
#  'sil providers perth',
#  'supported independent living perth',
#  'disability accommodation perth',
#  'sda providers perth',
#  'ndis providers near me',
#  'adelphi living mandurah',
#  'sil ndis',
#  'ndis housing perth',
#  'ndis providers perth',
#  'disability supported accommodation perth',
#  'sil accommodation perth',
#  'ndis',
#  'disability housing perth',
#  'specialist disability accommodation perth',
#  'sil',
#  'ndis events perth',
#  'ndis short term accommodation',
#  'disability service providers perth',
#  'disability accommodation wa',
#  'medium term accommodation ndis',
#  'medium term accommodation',
#  'disability housing',
#  'ndis respite accommodation',
#  'medium term accommodation perth',
#  'ndis sda housing',
#  'disability homes',
#  'sil housing',
#  'adelphi apartments perth',
#  'adelphi living jobs',
#  'ndis robust housing',
#  'ndis wa providers',
#  'sda living',
#  'disability services near me',
#  'adelphi care',
#  'support coordinators',
#  'sda payment',
#  'assisted living for schizophrenia near me',
#  'ndia wa',
#  'ndis sda application form',
#  'adelphi housing',
#  'disability support organisation',
#  'disability support services near me',
#  'independent living supplies',
#  'ndis support provider',
#  'ndis perth',
#  'sda ndis',
#  'supported independent living ndis',
#  'ndis supported independent living',
#  'disability accommodation',
#  'ndis sil',
#  'ndis provider perth',
#  'sil provider',
#  'ndis accommodation',
#  'ndis events',
#  'ndis sda',
#  'supported independent living',
#  'sda provider',
#  'sil providers',
#  'supported accommodation perth',
#  'respite accommodation',
#  'disability group homes perth',
#  'ndis support coordination perth',
#  'assisted living perth',
#  'sil accommodation',
#  'sda accommodation',
#  'sda house',
#  'short term accommodation perth',
#  'supported independent living providers',
#  'sda housing perth',
#  'ndis perth wa',
#  'disability services perth',
#  'supported living accommodation',
#  'independent living wa',
#  'independent living specialists',
#  'independent living housing',
#  'supported living',
#  'ndis provider wa',
#  'independent living',
#  'ndis service provider perth',
#  'disability respite accommodation',
#  'ndis events wa',
#  'sda house available',
#  'ndis events western australia',
#  'ndis services perth',
#  'what is sda',
#  'disability accommodation services',
#  'residential disability access perth',
#  'ndis service providers perth',
#  'ndis respite',
#  'disability short term accommodation',
#  'independent living perth',
#  'independent living services',
#  'respite care perth',
#  'sda living western australia',
#  'supported accommodation ndis',
#  'disability care services perth',
#  'sda homes',
#  'ndis providers wa',
#  'ndis independent living',
#  'short term accommodation ndis',
#  'independent living apartments for disabled',
#  'sda housing ndis',
#  'supported disability accommodation',
#  'ndis medium term accommodation',
#  'support coordinator perth',
#  'disability and independent living',
#  'assisted living',
#  'sda houses',
#  'ndis living',
#  'ndis housing',
#  'disability rental housing perth',
#  'independent living solutions',
#  'disability support services perth',
#  'independent living perth wa',
#  'ndis accommodation vacancies',
#  'sda apartments',
#  'ndis mental health perth',
#  'independent living western australia',
#  'independent living homes',
#  'ndis assisted living',
#  'independent living facilities near me',
#  'sil accomodation',
#  'short term accommodation disability',
#  'independent living near me',
#  'long stay accommodation perth',
#  'independent living disabled',
#  'freedom adelphi',
#  'atsa independent living expo',
#  'sda housing availability',
#  'able living',
#  'sda properties perth',
#  'assisted living apartments for disabled',
#  'living in perth',
#  'disability service provider perth',
#  'sda houding ndis',
#  'supported accommodation for people with disabilities',
#  'disability apartments',
#  'mental health housing wa',
#  'housing disability perth',
#  'specialist disability accommodation providers',
#  'sda perth',
#  'ndis sil rules',
#  'sil and sda',
#  'disability home care perth',
#  'disability home care',
#  'specialist support coordination perth',
#  'ndis properties perth',
#  'housing for people with disabilities perth',
#  'specialist disability housing perth',
#  'disability housing options perth',
#  'ndis sda properties perth',
#  'respite short term accommodation',
#  'sda participants',
#  'sil funding ndis',
#  'long term accommodation perth',
#  'disability residential homes',
#  'physical disability housing perth',
#  'disability housing solutions perth',
#  'independent living expo',
#  'alchera living',
#  'respite care perth wa',
#  'disability apartments perth',
#  'ndis sil providers',
#  'sil ndis funding',
#  'supported independent living disability',
#  'supported accommodation',
#  'ndis accommodation provider',
#  'independent living center perth',
#  'it provider perth',
#  'ndis provider',
#  'perth disability renovation',
#  'short term accommodation',
#  'erskine accommodation',
#  'housing for the disabled',
#  'perth disability services',
#  'sil disability housing',
#  'sda providers',
#  'sda wa',
#  'atsa',
#  'sda',
#  'supported living ndis',
#  'disability solutions for independent living',
#  'sda providers victoria',
#  'disabled accommodation perth',
#  'howard accommodation',
#  'disabled persons housing service',
#  'sil services',
#  'sda and sil',
#  'supported independant living facility',
#  'disability home care services',
#  'ndis supported accommodation',
#  'sda services',
#  'maddington accommodation',
#  'long term disability accommodation services',
#  'furnished accommodation perth',
#  'perth disability service provider and participant connection expo 2021',
#  'ndis joondalup',
#  'sil eligibility',
#  'independent living disability housing',
#  'disabled living accommodation',
#  'disability services',
#  'atsa expo',
#  'sil sda',
#  'medium-term accommodation',
#  'ndis homes',
#  'retirement living perth',
#  'home for disabled',
#  'adelphi apartments',
#  'national disability insurance scheme perth',
#  'content living homes',
#  'disability activities perth',
#  'sda categories',
#  'respite accommodation ndis',
#  'perth living',
#  'short term accommodation for disabled',
#  'independent living products perth wa',
#  'ndis mandurah',
#  'disability care wa',
#  'sda disability',
#  'ndis short term accommodation providers',
#  'sda payments',
#  'short term apartments perth wa',
#  'ndis rockingham',
#  'ndis sil eligibility',
#  'short stay accommodation perth',
#  'perth short term accommodation',
#  'ndis sda rules',
#  'specialist disability accommodation',
#  'ndis support perth',
#  'respite',
#  'howlong accommodation',
#  'adelphi apartments echuca',
#  'disability perth',
#  'sil perth',
#  'adelphi perth',
#  'share accommodation perth',
#  'specialised disability accommodation',
#  'sil supports',
#  'serviced apartments perth',
#  'the adelphi',
#  'what are the ndis supported indepented living',
#  'adelphi hotel perth',
#  'approved ndis providers in perth',
#  'sda home',
#  'perth apartments short stay',
#  'aussie living homes',
#  'altum living',
#  'what is sda ndis',
#  'ndis short term accommodation providers melbourne',
#  'sda contact',
#  'respite ndis',
#  'perth convention centre accommodation',
#  'what is sil',
#  'disability housing wa',
#  'perth expo',
#  'ndis sil provider',
#  'disabled living apartments',
#  'ndis bunbury',
#  'disability living support',
#  'ndis contact number',
#  'mental health supported accommodation perth',
#  'sda housing providers',
#  'sil supported independent living',
#  'ndis specialist disability accommodation',
#  'worker accommodation',
#  'short term accomodation ndis',
#  'short stay disability accommodation',
#  'sil funding',
#  'ndis number',
#  'high physical support sda',
#  'robust housing',
#  'disability group homes',
#  'supported independent living provider',
#  'ndis housing provider',
#  'ndis service providers wa',
#  'supported independent living accommodation',
#  'adventist senior living',
#  'ndis air conditioning',
#  'independent living services for the disabled',
#  'ndis short term accommodation clarmore',
#  'live your potential expo',
#  'disability service provider and participant connection expo 2021',
#  'disability care perth',
#  'ndis housing providers',
#  'it providers perth',
#  'ndis home and living',
#  'ndis wa',
#  'what is sil ndis',
#  'support coordinators perth',
#  'surgical house perth',
#  'perth share accommodation',
#  'wheelchair accessible accommodation perth',
#  'share accommodation in perth',
#  'supported disability accommodation ndis',
#  'adelphi beauty',
#  'perth disability service provider and participant connection expo 2021, \nperth convention and exhibition centre, 11 june',
#  'disability service provider and participant connection expo',
#  'ndis sil funding',
#  'short stay rentals perth',
#  'short stay apartments perth',
#  'disability',
#  'adelphi house',
#  'ndis apartments',
#  'ndis sil and sda',
#  'sil logo',
#  'robust sda',
#  'ndis tablet',
#  'accessible accommodation perth',
#  'community living perth',
#  'respite care in perth',
#  'workers accommodation',
#  'abilities expo perth 2021',
#  'sda funding',
#  'howard emery',
#  'ndis short term accomodation',
#  'ndis locations',
#  'sda funding ndis',
#  'get building sda',
#  'specialist disability accommodation providers victoria',
#  'share accomodation perth',
#  'ndis short term accommodation mental health',
#  'independent builders perth',
#  'disability organisations perth',
#  'ndis service providers',
#  'home and living ndis',
#  'ndis accommodation support',
#  'ndis short term accommodation providers victoria',
#  'ndis short term accommodation rules',
#  'contact sda',
#  'sil house',
#  'sil ltd',
#  'south perth short term accommodation',
#  'long term serviced apartments perth',
#  'medium term accommodation providers',
#  'home and living expo',
#  'short term apartments perth',
#  'living in perth wa',
#  'it provider',
#  'medium perth',
#  'ndis housing solutions',
#  'disability support perth',
#  'supported independent living wa',
#  'ndis service providers near me',
#  'sda solutions',
#  'sda and sil ndis',
#  'disability respite houses',
#  'fully accessible sda',
#  'sda access',
#  'specialist disability accommodation ndis',
#  'retirement living wa',
#  'adelphi insurance',
#  'independent living disability',
#  'independent living centre mandurah',
#  'service apartment perth',
#  'ndis provider registration wa',
#  'living independently',
#  'sdas',
#  'independant living',
#  'sda approved builders perth',
#  'short term disability accommodation',
#  'specialist disability accommodation services',
#  'ndis provider near me',
#  'assisted living mandurah',
#  'ndia sil',
#  'short term accomodation perth',
#  'sil support',
#  'alioth independents',
#  'handicap assisted living',
#  'short term stay perth',
#  'serviced apartments perth long term',
#  'short term rental perth',
#  'open homes perth',
#  'disability housing providers',
#  'sda approved housing',
#  'short term respite care',
#  'perth short stay apartments',
#  'sil living',
#  'disability living',
#  'ndis phone number',
#  'aldelphi',
#  'supported independent living homes',
#  'adelphi menu',
#  'sil disability',
#  'medium stay accommodation',
#  'sil houses',
#  'ndis short term accommodation rates',
#  'disability accomodation',
#  'ndis short term accommodation and assistance',
#  'avendelle assisted living',
#  'independent living centre perth',
#  'mental health accommodation perth',
#  'sda ndis rules',
#  'independent living accommodation',
#  'long stay accommodation perth cbd',
#  'living wa',
#  'sil homes',
#  'disability services mandurah',
#  'sda aged care',
#  'logo adelphi',
#  'shared accommodation',
#  'long term accommodation rockingham',
#  'disability housing solutions brisbane',
#  'clairvoyant perth',
#  'cheap serviced apartments perth',
#  'disabled living near me',
#  'aldephi',
#  'sda approved builders',
#  'ndis disability support',
#  'sda housing qld',
#  'housing ndis',
#  'ndis renovations perth',
#  'ndis support',
#  'abilities expo',
#  'sda sil',
#  'disability homes near me',
#  'improved liveability sda',
#  '27 adelphi road claremont',
#  'living expo',
#  'sda robust',
#  'living in wa',
#  'ndis expo',
#  'sda levels ndis',
#  'ndis supported living',
#  'short term accommodation perth wa',
#  'sil assessment ndis',
#  'short stay perth',
#  'difference between sil and sda',
#  'what does sil include',
#  'sda virtual room',
#  'improved living solutions',
#  'independant living solutions',
#  'home expo perth',
#  'disability respite',
#  'air adelphi',
#  'possibility disability services',
#  'adelphi group',
#  'home assist wa',
#  'supports sil',
#  's&a living',
#  'ndis wa contact',
#  'disability centre',
#  'disability facility near me',
#  'disability service',
#  'disability service provider',
#  'sil accommodation ndis',
#  'ndis houses',
#  'wa ndis',
#  'ndis accommodation perth',
#  'developing australian communities expo',
#  'sda high physical support',
#  'what is ndis sil',
#  'improved livability',
#  'ndis medium term accommodation providers',
#  'temporary accommodation perth',
#  'howard livings',
#  'sda care',
#  'ndis sda eligibility',
#  'short stays perth',
#  'short term accommodation in perth',
#  'independence living',
#  'adelphi care services',
#  'independent living centres australia',
#  'short term rentals perth wa',
#  'perth short stay accommodation',
#  'live in treeby',
#  'disability housing solutions',
#  'independent living centre wa',
#  'ndis accomodation',
#  'shared supported accommodation disability services',
#  'independant living specialists',
#  'accommodation perth region',
#  'adelphi logo',
#  'connection perth',
#  'short term accommodation mandurah',
#  'supported independent living ndis, supported independent living vacancies, \nsupported independent living sil',
#  'perth beauty expo',
#  'independent living equipment perth',
#  'ndis living assistance',
#  'homes west joondalup',
#  'perth serviced accommodation',
#  'sda logo',
#  'perth exhibitions',
#  'perth serviced apartment deal',
#  'shared accommodation perth',
#  'exhibitions perth',
#  'intellectual disability accommodation',
#  'diability services',
#  'disability facility',
#  'housing support',
#  'independent support services',
#  'living',
#  'ndis support workers near me',
#  'support independent living',
#  'disability home',
#  'ndis disability services',
#  'independent supported living',
#  'ndis home care',
#  'sil insurance',
#  'call ndis',
#  'disability support work',
#  'disability support worker',
#  'independent living facilities for disabled',
#  'ndis home',
#  'sda accomodation',
#  'supported independant living',
#  'ndis providers',
#  'ndis supplier',
#  'organisation',
#  'in home support ndis',
#  'medium term accomodation ndis',
#  'sil payments',
#  'disability expo perth 2021',
#  'adelphi freedom',
#  'sil ndia',
#  'disability expo perth',
#  'sda robust housing',
#  'connect expo',
#  'sda assessments',
#  'adelphi employment',
#  'apartments for people with disabilities',
#  'building ndis housing',
#  'now living',
#  'perth home expo',
#  'short term accommodation south perth',
#  'sda western australia',
#  'independent living ndis',
#  'nitropack scam',
#  'adelphi springs',
#  'independent living centre joondalup',
#  'disability services wa',
#  'disability independent living',
#  'ailfe perth',
#  'living and working in perth',
#  'short term lease perth',
#  'living perth',
#  'independent events perth',
#  'short term apartment rental perth',
#  'independent living centre',
#  'short term rentals perth',
#  'what is a sil',
#  'individualised living options',
#  'short term accomodation',
#  'freedom adelphi table',
#  'independent senior living',
#  'ndis jobs perth wa',
#  'independent assisted living',
#  'independent and assisted living communities',
#  'home modifications perth',
#  'disability care',
#  'in home respite care',
#  'sda design categories',
#  'access housing mandurah',
#  'living houses',
#  'access housing perth',
#  'what is sda funding',
#  'participant',
#  'short stay apartments',
#  'independent living facilities',
#  'simple approach perth',
#  'disability services midland',
#  'perth disability',
#  'independent living home',
#  'ndis provider logo',
#  'serviced accommodation perth',
#  'ndis accommodation providers',
#  'sda eligibility',
#  'respite care services perth',
#  'homes for disabled',
#  'independent care solution',
#  'adelphi house assisted living',
#  'adlephi',
#  'disability care center',
#  'disability care facility',
#  'disability care homes',
#  'disability holiday accommodation',
#  'disability houses',
#  'disability support worker agencies',
#  'disability supported accommodation',
#  'disability supported living',
#  'flexible living',
#  'indepedent living',
#  'independent disability',
#  'independent housing',
#  'independent living support',
#  'independent living victoria',
#  'indpendent living',
#  'living support',
#  'mason homes',
#  'ndis aged care providers',
#  'ndis disability housing',
#  'ndis near me',
#  'ndis provider in perth',
#  'ndis service',
#  'residential disability care facility',
#  'support living accommodation',
#  'support workers near me',
#  'supported living accomodation',
#  'supported living homes',
#  'supported living provider',
#  'supported living services',
#  'wa disability services',
#  'independent living program',
#  'independent living program for disabled',
#  'living living',
#  'ndis home care providers',
#  'ndis provider"',
#  'ndis telephone number',
#  'sda housing sydney',
#  'sda loan',
#  'sda loans',
#  'wheelchair accommodation',
#  '360 ndis',
#  'access living',
#  'afelphi',
#  'disablity support worker',
#  'disbaility',
#  'independent living for disabled',
#  'n.d.i.s',
#  'national disability services',
#  'ndia provider',
#  'ndis approved housing',
#  'ndis call',
#  'ndis provider number',
#  'ndis provider services',
#  'ndis specialist disability accommodation design standard',
#  'ndis.',
#  'ndis?',
#  'sda ndia',
#  'sil?',
#  'supported indepedent living',
#  '/sil',
#  'ndis aged care',
#  'ndis australia',
#  'ndis service provider',
#  'sda approval',
#  'sda housing',
#  'sda housing adelaide',
#  'sil solutions',
#  'accommodation for disabled adults',
#  'accommodation for people with disabilities',
#  'aged care supported living',
#  'contact ndis',
#  'ndis home and living supports',
#  'sda in ndis',
#  '"ndis aged care',
#  'adelphi 2021',
#  'nursing specialty',
#  'sda disability housing',
#  'sda housing brisbane',
#  'sda smart homes reviews',
#  'sil housing ndis',
#  'abilities expo 2021',
#  'adelphi management',
#  'robust housing meaning',
#  'rockingham disability expo',
#  'sil.',
#  'accommodation for disability',
#  'adelp',
#  'adelphi ceo',
#  'sda call',
#  'disability specialists',
#  'indepent living',
#  'coordinators',
#  'home for the disabled near me',
#  'atsa 2021',
#  'sda application ndis',
#  'ndis expo perth',
#  'ndis short term accommodation guidelines',
#  'perth disability expo',
#  'atsa perth',
#  'sda category',
#  'sil sda ndis',
#  'senior housing',
#  'what is an sil ndis',
#  'sda assessment',
#  'independent living bunbury',
#  '+independent +retirement +living',
#  'clicks adelphi',
#  'intellectual disability support services',
#  'who is sil',
#  'homes for independent living',
#  'independent retirement living',
#  'ndia perth',
#  'does ndis pay for accommodation',
#  'sda ceo',
#  'disability sil',
#  'independent home care',
#  'individual living options',
#  'perth long term accommodation',
#  'what is sil funding',
#  'sda apartment',
#  'ndis sda fact sheet',
#  'house sharing perth',
#  'disability providers perth',
#  'perth short term rental',
#  'treeby nursing home',
#  '"houses"',
#  'share housing perth',
#  'apartments perth short stay',
#  'flintwood disability services',
#  'what is ndis wa',
#  'sda virtual',
#  'weekly accommodation perth',
#  'assisted living disability',
#  'erskine wa',
#  'sil home',
#  'sda options',
#  'short term living',
#  'short term rentals in perth',
#  'home living expo',
#  'sda location',
#  'ndis application wa',
#  'what is ndis',
#  'best independent living communities',
#  'disability agencies perth',
#  'disability expo',
#  'shared supported accommodation',
#  'disability houses for rent near me',
#  'independent living houses',
#  'ndis services wa',
#  'short term accommodations',
#  'expo perth',
#  'independent community living',
#  'ndis eligibility wa',
#  'personal care assistance',
#  'share house perth',
#  'accommodation peel region wa',
#  'long term stay perth',
#  'sda structures',
#  'short term work perth',
#  'www.sil',
#  'independent living australia',
#  'living in mandurah',
#  'perth expo centre',
#  'nulsen disability services',
#  'ndis support wa',
#  'independent living communities',
#  'long term accommodation bunbury',
#  'ndis sil team',
#  'sda resources',
#  'self contained apartments perth',
#  'what is specialist disability accommodation',
#  'long term accommodation services',
#  'service apartments perth',
#  'short stay apartment perth',
#  'beauty expo perth',
#  'perthexpo',
#  'short term accommodation subiaco',
#  'adelphi laudale',
#  'ndis sil quote',
#  'old age care homes near me',
#  'serviced appartments perth',
#  'best it service provider perth',
#  'exhibitions in perth',
#  'home care wa',
#  'home living exhibition 2021',
#  'living in perth australia',
#  'perth home care services',
#  'short term accommodation joondalup',
#  'sda vacancies',
#  'adelphi health services',
#  'ndis help with housing',
#  'aged care residences',
#  'independent living options',
#  'outdoor living mandurah',
#  'short term accommodation ndis providers',
#  'abode living',
#  'disabled houses',
#  'independent living units adelaide',
#  'respite care homes in perth',
#  'disability support accommodation',
#  'fifo short term accommodation perth',
#  'independent living centres',
#  'personal services perth wa',
#  'short term furnished rentals perth',
#  'independent living solution',
#  'dali accommodation',
#  'independent retirement living adelaide',
#  'residential respite high care',
#  'disabled independent living housing',
#  'respite care ndis',
#  'adelphi suites',
#  'disability employment services providers perth',
#  'disability house',
#  'home care perth wa',
#  'long term accommodation near me',
#  'independent living hobart',
#  'bold living',
#  'disabled living manchester',
#  'disability insurance perth',
#  'housing for people with disabilities',
#  'disability support providers',
#  'live in specialist care']

# %% [markdown]
# # Start clustering our keywords using Machine Learning sklearn library

# %%
# Define our keyword clustering model with sklearn and TfidfVectorizer (using DBSCAN and not Kmean)
tfidf_vectorizer = TfidfVectorizer(max_df=0.2, max_features=10000,min_df=0.01,use_idf=True, ngram_range=(1,2))

# Import our keyword list for Keyword Clustering
tfidf_matrix = tfidf_vectorizer.fit_transform(keywords)

# Define settings for cluster adjustment (number and size of clusters)
ds = DBSCAN(eps=0.7, min_samples=5).fit(tfidf_matrix)
clusters = ds.labels_

# %% [markdown]
# ## Create a dataframe to hold our keyword clusters

# %%
# Create a dataframe for our clusters
cluster_df = pd.DataFrame(clusters, columns=['Cluster Number'])

# Merge our cluster df with our top queries df
result = pd.merge(cluster_df, top_queries, left_index=True, right_index=True)

# We group our keywords by cluster number and separate them with a comma
clusters_queries = result.groupby(['Cluster Number'])['Top queries'].apply(', '.join).reset_index()

# Extend Column and Row width for a better readability 
pd.set_option('max_colwidth', 400)
pd.set_option('max_rows', 100)

clusters_queries
# Out:
#     Cluster Number  \
# 0               -1
# 1                0
# 2                1
# 3                2
# 4                3
# 5                4
# 6                5
# 7                6
# 8                7
# 9                8
# 10               9
# 11              10
# 12              11
# 13              12
# 14              13
# 15              14
# 16              15
# 17              16
# 18              17
# 19              18
# 20              19
# 21              20
# 22              21
# 23              22
# 24              23
# 25              24
# 26              25
# 27              26
# 28              27
# 29              28
# 30              29
# 31              30
# 32              31
# 33              32
# 34              33
# 35              34
# 36              35
# 37              36
# 38              37
# 39              38
# 40              39
# 41              40
# 42              41
# 43              42
# 44              43
# 45              44
# 46              45
# 47              46
# 48              47
# 49              48
# 50              49
# 51              50
# 52              51
#
#                                                                                                                                                                                                                                                                                                                                                                                                         Top queries
# 0   adelphi living mandurah, sil housing, ndis wa providers, adelphi care, assisted living for schizophrenia near me, adelphi housing, ndis support provider, sil providers, sda accommodation, ndis services perth, ndis providers wa, disability and independent living, independent living solutions, sda apartments, independent living homes, long stay accommodation perth, independent living disabled, a...
# 1   adelphi living, adelphi, adelphi living jobs, freedom adelphi, adelphi perth, the adelphi, adelphi hotel perth, adelphi beauty, adelphi insurance, adelphi menu, logo adelphi, 27 adelphi road claremont, air adelphi, adelphi group, adelphi logo, adelphi freedom, adelphi employment, adelphi springs, freedom adelphi table, adelphi management, adelphi ceo, clicks adelphi, adelphi laudale, adelphi s...
# 2                                                                                                                                                                                  sil providers perth, sda providers perth, ndis providers perth, disability service providers perth, ndis service providers perth, it providers perth, disability providers perth, disability employment services providers perth
# 3   supported independent living perth, supported independent living ndis, ndis supported independent living, supported independent living, supported independent living providers, supported independent living disability, sil supported independent living, supported independent living provider, supported independent living accommodation, supported independent living wa, supported independent living ...
# 4   ndis providers near me, disability services near me, disability support services near me, independent living facilities near me, independent living near me, ndis service providers near me, ndis provider near me, disabled living near me, disability homes near me, disability facility near me, ndis support workers near me, ndis near me, support workers near me, home for the disabled near me, disa...
# 5                                                                                                                                                          sil ndis, sil, sil accommodation, sil eligibility, sil perth, sil supports, sil logo, sil ltd, ndia sil, sil living, sil disability, sil assessment ndis, supports sil, sil insurance, sil payments, sil ndia, sil?, /sil, sil., disability sil, www.sil
# 6   ndis housing perth, disability housing perth, disability housing, disability rental housing perth, specialist disability housing perth, disability housing options perth, physical disability housing perth, disability housing solutions perth, sil disability housing, independent living disability housing, disability housing wa, disability housing providers, disability housing solutions brisbane, ...
# 7                           disability supported accommodation perth, supported accommodation perth, supported accommodation ndis, supported accommodation for people with disabilities, supported accommodation, ndis supported accommodation, mental health supported accommodation perth, shared supported accommodation disability services, disability supported accommodation, shared supported accommodation
# 8                                                                      sil accommodation perth, furnished accommodation perth, share accommodation perth, wheelchair accessible accommodation perth, accessible accommodation perth, mental health accommodation perth, ndis accommodation perth, temporary accommodation perth, accommodation perth region, shared accommodation perth, weekly accommodation perth
# 43                                                                                                      atsa expo, perth expo, live your potential expo, abilities expo, living expo, ndis expo, developing australian communities expo, perth beauty expo, disability expo perth, connect expo, rockingham disability expo, ndis expo perth, perth disability expo, disability expo, expo perth, beauty expo perth
# 44                                                                                                                                independent living apartments for disabled, home for disabled, short term accommodation for disabled, independent living facilities for disabled, homes for disabled, independent living program for disabled, independent living for disabled, accommodation for disabled adults
# 45                                                                                           short stay accommodation perth, perth apartments short stay, short stay disability accommodation, short stay rentals perth, short stay apartments perth, perth short stay apartments, short stay perth, perth short stay accommodation, short stay apartments, apartments perth short stay, short stay apartment perth
# 46                                                                                                                                                                                                                                                                                                         sil accomodation, share accomodation perth, disability accomodation, ndis accomodation, sda accomodation
# 47                                                                                                                                                                                                                                                              ndis home and living, home and living ndis, home and living expo, home expo perth, perth home expo, ndis home and living supports, home living expo
# 48                                                                                                                                                                                                                                                independent living centre mandurah, independent living centre perth, independent living centre wa, independent living centre joondalup, independent living centre
# 49                                                                                                                                                                                                                                                                              sda aged care, sda care, independent care solution, ndis aged care, "ndis aged care, personal care assistance, aged care residences
# 50                                                                                                                                                                                                                                                                                                    ndis housing solutions, sda solutions, improved living solutions, independant living solutions, sil solutions
# 51                                                                                                                                                                                                                                                                                                                    sda home, disability home, ndis home, home modifications perth, treeby nursing home, sil home
# 52                                                                                                                                                                                                                                                                                                             abilities expo perth 2021, adelphi 2021, abilities expo 2021, atsa 2021, home living exhibition 2021

# %% [markdown]
# ## Use the same ML model on each cluster so we can name our clusters automatically

# %%
# Create an empty list to store our cluster names
cluster_name = []

# Use Iterrows and tfIdVectorizer to get all words and their TF-IDF Score per cluster
for index, row in clusters_queries.iterrows():
    
    queries = row['Top queries']
    queries = [queries]

    # Add a stop_words function to drop irrelevant words (ex: “a”, “the”, “is”, “are”, "and" etc...)
    my_stop_words = text.ENGLISH_STOP_WORDS

    # Run tfIdfVectorizer for each cluster
    tfIdfVectorizer=TfidfVectorizer(use_idf=True, stop_words=my_stop_words)
    tfIdf = tfIdfVectorizer.fit_transform(queries)
    query_score_cluster = pd.DataFrame(tfIdf[0].T.todense(), index=tfIdfVectorizer.get_feature_names(), columns=["TF-IDF Score"])
    query_score_cluster = query_score_cluster.sort_values('TF-IDF Score', ascending=False)

    # Get the top 3 queries (selected by highest scores) per cluster and get them into lists, clean words of commas and ''
    top_three_queries = query_score_cluster.index[:3]
    top_three_queries_list = top_three_queries.values.tolist()
    top_three_queries_list = str(top_three_queries_list).replace(',', '')
    top_three_queries_list = str(top_three_queries_list).replace('[','').replace(']','')
    top_three_queries_list = str(top_three_queries_list).replace("'","")

    # Append our top 3 queries to our cluster_name list
    cluster_name.append(top_three_queries_list)
    
    # Create a Cluster Name dataframe    
    cluster_name_df = pd.DataFrame({'Cluster Name': cluster_name})

cluster_name_df
# Out:
#                            Cluster Name
# 0                     perth ndis living
# 1                 adelphi freedom perth
# 2            perth providers disability
# 3          independent living supported
# 4                  near disability ndis
# 5                   sil disability ndia
# 6              housing disability perth
# 7    accommodation supported disability
# 8        accommodation perth accessible
# 9                     living ndis perth
# 10  accommodation disability specialist
# 11             term short accommodation
# 12            accommodation medium term
# 13           respite accommodation ndis
# 14                     housing sda ndis
# 15               homes disability group
# 16             apartments perth adelphi
# 17                  housing ndis robust
# 18                       sda ndis perth
# 19                   support ndis perth
# 20                       wa ndis living
# 21             disability support perth
# 22             independent living perth
# 23   accommodation disability supported
# 24                     sil ndis funding
# 25                     ndis provider wa
# 26              accommodation ndis dali
# 27          assisted living independent
# 28                      house perth sda
# 29            disability services perth
# 30                living supported ndis
# 31          provider service disability
# 32             australia living western
# 33                         ndis sil sda
# 34           disability perth insurance
# 35                   care respite perth
# 36             care disability facility
# 37             houses disability living
# 38           perth living accommodation
# 39                         sda sil ndis
# 40                 care home disability
# 41              accommodation long term
# 42          provider ndis accommodation
# 43                expo perth disability
# 44          disabled independent living
# 45                     short stay perth
# 46         accomodation disability ndis
# 47                     home living expo
# 48            centre independent living
# 49                       care aged ndis
# 50             solutions living housing
# 51        home disability modifications
# 52                  2021 abilities expo

# %% [markdown]
# # Merge our dataframes so we can see all of our keywords grouped into different clusters and their names automatically generated. We can make sure it is matching properly

# %%
# Merge cluster_name_df with clusters_queries so we can have them matching and double check the cluster names match with our queries
clusters = pd.merge(cluster_name_df, clusters_queries, left_index=True, right_index=True)
clusters
# Out:
#                            Cluster Name  Cluster Number  \
# 0                     perth ndis living              -1
# 1                 adelphi freedom perth               0
# 2            perth providers disability               1
# 3          independent living supported               2
# 4                  near disability ndis               3
# 5                   sil disability ndia               4
# 6              housing disability perth               5
# 7    accommodation supported disability               6
# 8        accommodation perth accessible               7
# 9                     living ndis perth               8
# 10  accommodation disability specialist               9
# 11             term short accommodation              10
# 12            accommodation medium term              11
# 13           respite accommodation ndis              12
# 14                     housing sda ndis              13
# 15               homes disability group              14
# 16             apartments perth adelphi              15
# 17                  housing ndis robust              16
# 18                       sda ndis perth              17
# 19                   support ndis perth              18
# 20                       wa ndis living              19
# 21             disability support perth              20
# 22             independent living perth              21
# 23   accommodation disability supported              22
# 24                     sil ndis funding              23
# 25                     ndis provider wa              24
# 26              accommodation ndis dali              25
# 27          assisted living independent              26
# 28                      house perth sda              27
# 29            disability services perth              28
# 30                living supported ndis              29
# 31          provider service disability              30
# 32             australia living western              31
# 33                         ndis sil sda              32
# 34           disability perth insurance              33
# 35                   care respite perth              34
# 36             care disability facility              35
# 37             houses disability living              36
# 38           perth living accommodation              37
# 39                         sda sil ndis              38
# 40                 care home disability              39
# 41              accommodation long term              40
# 42          provider ndis accommodation              41
# 43                expo perth disability              42
# 44          disabled independent living              43
# 45                     short stay perth              44
# 46         accomodation disability ndis              45
# 47                     home living expo              46
# 48            centre independent living              47
# 49                       care aged ndis              48
# 50             solutions living housing              49
# 51        home disability modifications              50
# 52                  2021 abilities expo              51
#
#                                                                                                                                                                                                                                                                                                                                                                                                         
# 14                                                                                                                                                                                                             ndis sda housing, sda housing perth, sda housing ndis, sda housing availability, sda housing providers, sda housing qld, sda housing sydney, sda housing, sda housing adelaide, sda housing brisbane
# 15                                                                                                                                                  disability homes, disability group homes perth, sda homes, disability residential homes, ndis homes, content living homes, aussie living homes, disability group homes, open homes perth, sil homes, homes west joondalup, mason homes, sda smart homes reviews
# 16                                                                                                                                                                                      adelphi apartments perth, disability apartments perth, adelphi apartments, adelphi apartments echuca, serviced apartments perth, cheap serviced apartments perth, self contained apartments perth, service apartments perth
# 17                                                                                                                                                                ndis robust housing, ndis housing, housing disability perth, robust housing, sda approved housing, housing ndis, sda robust housing, building ndis housing, ndis approved housing, robust housing meaning, senior housing, ndis help with housing
# 18  sda living, sda payment, ndis sda application form, sda ndis, ndis sda, sda properties perth, sda houding ndis, sda perth, ndis sda properties perth, sda participants, sda, sda categories, sda payments, ndis sda rules, sda contact, robust sda, get building sda, contact sda, fully accessible sda, sda access, sda approved builders perth, sda ndis rules, sda approved builders, improved liveabilit...
# 19                                                                 support coordinators, ndis support coordination perth, support coordinator perth, ndis support perth, disability living support, high physical support sda, support coordinators perth, ndis accommodation support, sil support, ndis support, sda high physical support, living support, support living accommodation, disablity support worker
# 20                                                                                                                                                                                                                          ndia wa, ndis events wa, sda wa, ndis wa, retirement living wa, living wa, ndis wa contact, wa ndis, erskine wa, ndis application wa, ndis eligibility wa, accommodation peel region wa
# 21                                                                                          disability support organisation, disability support services perth, disability support perth, ndis disability support, disability support work, disability support worker, disability support worker agencies, intellectual disability support services, disability support accommodation, disability support providers
# 22  independent living supplies, ndis perth wa, independent living wa, independent living specialists, independent living housing, independent living, independent living perth, independent living services, ndis independent living, independent living perth wa, independent living center perth, independent living products perth wa, independent builders perth, independent living disability, independen...
# 23                                                                                                                               disability accommodation perth, disability accommodation wa, disability accommodation, disability accommodation services, supported disability accommodation, specialised disability accommodation, supported disability accommodation ndis, intellectual disability accommodation
# 24                                                                                                                                                                                                                          ndis sil, ndis sil rules, sil funding ndis, ndis sil providers, sil ndis funding, ndis sil eligibility, ndis sil provider, sil funding, ndis sil funding, ndis sil team, ndis sil quote
# 25                                                                                                                                                                                                                                            ndis provider perth, ndis provider wa, ndis provider, ndis provider registration wa, ndis provider logo, ndis provider", ndis provider number, ndis provider services
# 26                                                                                                                       ndis accommodation, ndis accommodation vacancies, erskine accommodation, howard accommodation, maddington accommodation, howlong accommodation, worker accommodation, perth share accommodation, workers accommodation, shared accommodation, wheelchair accommodation, dali accommodation
# 27                                                                                                                                                                assisted living perth, assisted living, ndis assisted living, assisted living mandurah, handicap assisted living, avendelle assisted living, independent assisted living, independent and assisted living communities, assisted living disability
# 28                                                                                                                                                                                                                                                                         sda house, sda house available, surgical house perth, adelphi house, sil house, house sharing perth, share house perth, disability house
# 29                                                                         disability services perth, perth disability services, disability services, disability services mandurah, possibility disability services, ndis disability services, disability services wa, disability services midland, wa disability services, national disability services, flintwood disability services, nulsen disability services
# 30                                                                                                               supported living accommodation, supported living, supported living ndis, ndis supported living, independent supported living, disability supported living, supported living accomodation, supported living homes, supported living provider, supported living services, aged care supported living
# 31  ndis service provider perth, disability service provider perth, perth disability service provider and participant connection expo 2021, disability service provider and participant connection expo 2021, perth disability service provider and participant connection expo 2021, \nperth convention and exhibition centre, 11 
# 50                                                                                                                                                                                                                                                                                                    ndis housing solutions, sda solutions, improved living solutions, independant living solutions, sil solutions
# 51                                                                                                                                                                                                                                                                                                                    sda home, disability home, ndis home, home modifications perth, treeby nursing home, sil home
# 52                                                                                                                                                                                                                                                                                                             abilities expo perth 2021, adelphi 2021, abilities expo 2021, atsa 2021, home living exhibition 2021

# %% [markdown]
# ## We only retain our Cluster names and numbers together

# %%
# splited_clusters = pd.concat([pd.Series(row['Cluster Name'], row['Top queries'].split(','))              
#                     for _, row in clusters.iterrows()]).reset_index()
cluster_name_nb = clusters[["Cluster Name", "Cluster Number"]]
cluster_name_nb.head()
# Out:
#                    Cluster Name  Cluster Number
# 0             perth ndis living              -1
# 1         adelphi freedom perth               0
# 2    perth providers disability               1
# 3  independent living supported               2
# 4          near disability ndis               3

# %%
# Merge it with our machine learning results
clusters_queries = pd.merge(result, cluster_name_nb, how="inner", on="Cluster Number")
clusters_queries.head()
# Out:
#    Cluster Number          Top queries           Cluster Name
# 0               0       adelphi living  adelphi freedom perth
# 1               0              adelphi  adelphi freedom perth
# 2               0  adelphi living jobs  adelphi freedom perth
# 3               0      freedom adelphi  adelphi freedom perth
# 4               0        adelphi perth  adelphi freedom perth

# %%
# Merge it with the original dataset to get the matching query performances
final_df = pd.merge(df, clusters_queries, how="inner", on="Top queries")
final_df
# Out:
#                               Top queries  Clicks  Impressions     CTR  \
# 0                          adelphi living     255          765  33.33%
# 1                                 adelphi      15          314   4.78%
# 2                     sil providers perth      11           98  11.22%
# 3      supported independent living perth       8          327   2.45%
# 4          disability accommodation perth       4          645   0.62%
# ..                                    ...     ...          ...     ...
# 790            disabled living manchester       0            1      0%
# 791            disability insurance perth       0            1      0%
# 792  housing for people with disabilities       0            1      0%
# 793          disability support providers       0            1      0%
# 794               live in specialist care       0            1      0%
#
#      Position  Cluster Number                        Cluster Name
# 0        1.06               0               adelphi freedom perth
# 1       10.04               0               adelphi freedom perth
# 2        2.20               1          perth providers disability
# 3        8.10               2        independent living supported
# 4       21.36              22  accommodation disability supported
# ..        ...             ...                                 ...
# 790    134.00              -1                   perth ndis living
# 791    141.00              33          disability perth insurance
# 792    196.00              -1                   perth ndis living
# 793    199.00              20            disability support perth
# 794    276.00              -1                   perth ndis living
#
# [795 rows x 7 columns]

# %% [markdown]
# ### We now have a complete dataframe with our queries, performances and corresponding cluster names.
#
# ### It means we can now perform data analysis per cluster, which can be useful especially if you have a lot of queries

# %% [markdown]
# ## Export our dataframe to a Google Spreadsheet (previously created) so it can be read dynamically with Tableau and Google Data Studio

# %%
# Use of gspread to connect our Google Spreadsheet to our final dataframe
scope = ['https://www.googleapis.com/auth/spreadsheets',
        'https://www.googleapis.com/auth/drive']

# Load credentials (not on the github / heroku folder, has to be replaced manually for safety purposes)
creds = Credentials.from_service_account_file("default.json", scopes=scope)
client = gspread.authorize(creds)

# Loading a Google Spreadsheet created before
google_sh = client.open("keyword_clustering")

# Selecting the sheet
sheet1 = google_sh.get_worksheet(0)

# Clearing output
sheet1.clear()

# Send our pandas dataframe to the google spreadsheet (you will be able to load it from Tableau and Google Data Studio)
df_google = set_with_dataframe(sheet1, final_df)

# %%
# Read our Google Spreadsheet to confirm the data has been correctly exported ('Unnamed' are the empty cells)
df_google = get_as_dataframe(sheet1)
df_google.head(20)
# Out:
#                                   Top queries  Clicks  Impressions     CTR  \
# 0                              adelphi living   255.0        765.0  0.3333
# 1                                     adelphi    15.0        314.0  0.0478
# 2                         sil providers perth    11.0         98.0  0.1122
# 3          supported independent living perth     8.0        327.0  0.0245
# 4              disability accommodation perth     4.0        645.0  0.0062
# 5                         sda providers perth     4.0         39.0  0.1026
# 6                      ndis providers near me     3.0         54.0  0.0556
# 7                     adelphi living mandurah     3.0         18.0  0.1667
# 8                                    sil ndis     2.0        906.0  0.0022
# 9                          ndis housing perth     2.0        454.0  0.0044
# 10                       ndis providers perth     2.0        357.0  0.0056
# 11   disability supported accommodation perth     2.0        222.0  0.0090
# 12                    sil accommodation perth     2.0         13.0  0.1538
# 13                                       ndis     1.0        974.0  0.0010
# 14                   disability housing perth     1.0        498.0  0.0020
# 15  specialist disability accommodation perth     1.0        434.0  0.0023
# 16                                        sil     1.0        342.0  0.0029
# 17                          ndis events perth     1.0        264.0  0.0038
# 18              ndis short term accommodation     1.0        261.0  0.0038
# 19         disability service providers perth     1.0        223.0  0.0045
#
#     Position  Cluster Number                         Cluster Name  Unnamed: 7  \
# 0       1.06             0.0                adelphi freedom perth         NaN
# 1      10.04             0.0                adelphi freedom perth         NaN
# 2       2.20             1.0           perth providers disability         NaN
# 3       8.10             2.0         independent living supported         NaN
# 4      21.36            22.0   accommodation disability supported         NaN
# 5       7.21             1.0           perth providers disability         NaN
# 6       1.00             3.0                 near disability ndis         NaN
# 7       1.06            -1.0                    perth ndis living         NaN
# 8      37.77             4.0                  sil disability ndia         NaN
# 9      10.86             5.0             housing disability perth         NaN
# 10     48.13             1.0           perth providers disability         NaN
# 11     13.06             6.0   accommodation supported disability         NaN
# 12      4.38             7.0       accommodation perth accessible         NaN
# 13      3.13             8.0                    living ndis perth         NaN
# 14     24.32             5.0             housing disability perth         NaN
# 15      8.61             9.0  accommodation disability specialist         NaN
# 16      5.02             4.0                  sil disability ndia         NaN
# 17     15.02             8.0                    living ndis perth         NaN
# 18     29.24            10.0             term short accommodation         NaN
# 19     66.67             1.0           perth providers disability         NaN
#
#     Unnamed: 8  Unnamed: 9  ...  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# 0          NaN         NaN  ...          NaN          NaN          NaN
# 1          NaN         NaN  ...          NaN          NaN          NaN
# 2          NaN         NaN  ...          NaN          NaN          NaN
# 3          NaN         NaN  ...          NaN          NaN          NaN
# 4          NaN         NaN  ...          NaN          NaN          NaN
# 5          NaN         NaN  ...          NaN          NaN          NaN
# 6          NaN         NaN  ...          NaN          NaN          NaN
# 7          NaN         NaN  ...          NaN          NaN          NaN
# 8          NaN         NaN  ...          NaN          NaN          NaN
# 9          NaN         NaN  ...          NaN          NaN          NaN
# 10         NaN         NaN  ...          NaN          NaN          NaN
# 11         NaN         NaN  ...          NaN          NaN          NaN
# 12         NaN         NaN  ...          NaN          NaN          NaN
# 13         NaN         NaN  ...          NaN          NaN          NaN
# 14         NaN         NaN  ...          NaN          NaN          NaN
# 15         NaN         NaN  ...          NaN          NaN          NaN
# 16         NaN         NaN  ...          NaN          NaN          NaN
# 17         NaN         NaN  ...          NaN          NaN          NaN
# 18         NaN         NaN  ...          NaN          NaN          NaN
# 19         NaN         NaN  ...          NaN          NaN          NaN
#
#     Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN          NaN
# 7           NaN          NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN          NaN
# 9           NaN          NaN          NaN          NaN          NaN
# 10          NaN          NaN          NaN          NaN          NaN
# 11          NaN          NaN          NaN          NaN          NaN
# 12          NaN          NaN          NaN          NaN          NaN
# 13          NaN          NaN          NaN          NaN          NaN
# 14          NaN          NaN          NaN          NaN          NaN
# 15          NaN          NaN          NaN          NaN          NaN
# 16          NaN          NaN          NaN          NaN          NaN
# 17          NaN          NaN          NaN          NaN          NaN
# 18          NaN          NaN          NaN          NaN          NaN
# 19          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 24  Unnamed: 25
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4           NaN          NaN
# 5           NaN          NaN
# 6           NaN          NaN
# 7           NaN          NaN
# 8           NaN          NaN
# 9           NaN          NaN
# 10          NaN          NaN
# 11          NaN          NaN
# 12          NaN          NaN
# 13          NaN          NaN
# 14          NaN          NaN
# 15          NaN          NaN
# 16          NaN          NaN
# 17          NaN          NaN
# 18          NaN          NaN
# 19          NaN          NaN
#
# [20 rows x 26 columns]

# %% [markdown]
# ## Export our final_df Dataframe to sqlite for further purposes (ex: load JSON URL data with Plotly or D3)

# %%
# SQL Alchemy
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
# Create connection
engine = create_engine('sqlite:///keyword_clustering.sqlite', echo=True)
conn = engine.connect()
# Out:
# 2021-09-07 10:37:40,785 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-09-07 10:37:40,792 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:40,795 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-09-07 10:37:40,797 INFO sqlalchemy.engine.base.Engine ()

# %%
# Reflect an existing database into a new model
Base = automap_base()
Base.prepare(engine, reflect=True)
# Out:
# 2021-09-07 10:37:40,819 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-09-07 10:37:40,822 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:40,827 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("keyword_clustering")
# 2021-09-07 10:37:40,830 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:40,837 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'keyword_clustering' AND type = 'table'
# 2021-09-07 10:37:40,839 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:40,844 INFO sqlalchemy.engine.base.Engine PRAGMA main.foreign_key_list("keyword_clustering")
# 2021-09-07 10:37:40,847 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:40,850 INFO sqlalchemy.engine.base.Engine PRAGMA temp.foreign_key_list("keyword_clustering")
# 2021-09-07 10:37:40,852 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:40,854 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'keyword_clustering' AND type = 'table'
# 2021-09-07 10:37:40,856 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:40,863 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("keyword_clustering")
# 2021-09-07 10:37:40,864 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:40,868 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_info("ix_keyword_clustering_index")
# 2021-09-07 10:37:40,870 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:40,872 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("keyword_clustering")
# 2021-09-07 10:37:40,877 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:40,881 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_info("ix_keyword_clustering_index")
# 2021-09-07 10:37:40,883 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:40,887 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'keyword_clustering' AND type = 'table'
# 2021-09-07 10:37:40,890 INFO sqlalchemy.engine.base.Engine ()

# %%
# Export our dataframe to SQL and replace the data if the table is already there
final_df.to_sql("keyword_clustering", conn, if_exists="replace")
# Out:
# 2021-09-07 10:37:40,921 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("keyword_clustering")
# 2021-09-07 10:37:40,923 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:40,928 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("keyword_clustering")
# 2021-09-07 10:37:40,931 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:40,934 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-09-07 10:37:40,936 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:40,939 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("keyword_clustering")
# 2021-09-07 10:37:40,941 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:40,947 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'keyword_clustering' AND type = 'table'
# 2021-09-07 10:37:40,949 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:40,952 INFO sqlalchemy.engine.base.Engine PRAGMA main.foreign_key_list("keyword_clustering")
# 2021-09-07 10:37:40,953 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:40,955 INFO sqlalchemy.engine.base.Engine PRAGMA temp.foreign_key_list("keyword_clustering")
# 2021-09-07 10:37:40,957 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:40,959 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'keyword_clustering' AND type = 'table'
# 2021-09-07 10:37:40,961 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:40,964 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("keyword_clustering")
# 2021-09-07 10:37:40,967 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:40,970 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_info("ix_keyword_clustering_index")
# 2021-09-07 10:37:40,972 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:40,977 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("keyword_clustering")
# 2021-09-07 10:37:40,978 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:40,981 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_info("ix_keyword_clustering_index")
# 2021-09-07 10:37:40,983 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:40,985 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'keyword_clustering' AND type = 'table'
# 2021-09-07 10:37:40,986 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:40,988 INFO sqlalchemy.engine.base.Engine
# DROP TABLE keyword_clustering
# 2021-09-07 10:37:40,989 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:41,000 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-09-07 10:37:41,004 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE keyword_clustering (
# 	"index" BIGINT,
# 	"Top queries" TEXT,
# 	"Clicks" BIGINT,
# 	"Impressions" BIGINT,
# 	"CTR" TEXT,
# 	"Position" FLOAT,
# 	"Cluster Number" BIGINT,
# 	"Cluster Name" TEXT
# )
#
#
# 2021-09-07 10:37:41,005 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:41,014 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-09-07 10:37:41,016 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_keyword_clustering_index ON keyword_clustering ("index")
# 2021-09-07 10:37:41,017 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:41,026 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-09-07 10:37:41,030 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-09-07 10:37:41,044 INFO sqlalchemy.engine.base.Engine INSERT INTO keyword_clustering ("index", "Top queries", "Clicks", "Impressions", "CTR", "Position", "Cluster Number", "Cluster Name") VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2021-09-07 10:37:41,046 INFO sqlalchemy.engine.base.Engine ((0, 'adelphi living', 255, 765, '33.33%', 1.06, 0, 'adelphi freedom perth'), (1, 'adelphi', 15, 314, '4.78%', 10.04, 0, 'adelphi freedom perth'), (2, 'sil providers perth', 11, 98, '11.22%', 2.2, 1, 'perth providers disability'), (3, 'supported independent living perth', 8, 327, '2.45%', 8.1, 2, 'independent living supported'), (4, 'disability accommodation perth', 4, 645, '0.62%', 21.36, 22, 'accommodation disability supported'), (5, 'sda providers perth', 4, 39, '10.26%', 7.21, 1, 'perth providers disability'), (6, 'ndis providers near me', 3, 54, '5.56%', 1.0, 3, 'near disability ndis'), (7, 'adelphi living mandurah', 3, 18, '16.67%', 1.06, -1, 'perth ndis living')  ... displaying 10 of 795 total bound parameter sets ...  (793, 'disability support providers', 0, 1, '0%', 199.0, 20, 'disability support perth'), (794, 'live in specialist care', 0, 1, '0%', 276.0, -1, 'perth ndis living'))
# 2021-09-07 10:37:41,058 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
# Reflect Database into ORM classes
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# 2021-09-07 10:37:41,098 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-09-07 10:37:41,100 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:41,104 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("keyword_clustering")
# 2021-09-07 10:37:41,105 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:41,110 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'keyword_clustering' AND type = 'table'
# 2021-09-07 10:37:41,113 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:41,117 INFO sqlalchemy.engine.base.Engine PRAGMA main.foreign_key_list("keyword_clustering")
# 2021-09-07 10:37:41,119 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:41,120 INFO sqlalchemy.engine.base.Engine PRAGMA temp.foreign_key_list("keyword_clustering")
# 2021-09-07 10:37:41,122 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:41,123 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'keyword_clustering' AND type = 'table'
# 2021-09-07 10:37:41,125 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:41,128 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("keyword_clustering")
# 2021-09-07 10:37:41,130 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:41,133 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_info("ix_keyword_clustering_index")
# 2021-09-07 10:37:41,134 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:41,139 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("keyword_clustering")
# 2021-09-07 10:37:41,140 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:41,144 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_info("ix_keyword_clustering_index")
# 2021-09-07 10:37:41,145 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:41,149 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'keyword_clustering' AND type = 'table'
# 2021-09-07 10:37:41,150 INFO sqlalchemy.engine.base.Engine ()
# []

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
# Use `engine.execute` to select and display the first 10 rows from the station table
engine.execute('SELECT * FROM keyword_clustering LIMIT 5').fetchall()
# Out:
# 2021-09-07 10:37:41,179 INFO sqlalchemy.engine.base.Engine SELECT * FROM keyword_clustering LIMIT 5
# 2021-09-07 10:37:41,180 INFO sqlalchemy.engine.base.Engine ()
# [(0, 'adelphi living', 255, 765, '33.33%', 1.06, 0, 'adelphi freedom perth'),
#  (1, 'adelphi', 15, 314, '4.78%', 10.04, 0, 'adelphi freedom perth'),
#  (2, 'sil providers perth', 11, 98, '11.22%', 2.2, 1, 'perth providers disability'),
#  (3, 'supported independent living perth', 8, 327, '2.45%', 8.1, 2, 'independent living supported'),
#  (4, 'disability accommodation perth', 4, 645, '0.62%', 21.36, 22, 'accommodation disability supported')]

# %%
# Query keyword_clustering in the the Database
data = pd.read_sql("SELECT * FROM keyword_clustering", conn)
data
# Out:
# 2021-09-07 10:37:41,196 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("SELECT * FROM keyword_clustering")
# 2021-09-07 10:37:41,197 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:41,199 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("SELECT * FROM keyword_clustering")
# 2021-09-07 10:37:41,201 INFO sqlalchemy.engine.base.Engine ()
# 2021-09-07 10:37:41,202 INFO sqlalchemy.engine.base.Engine SELECT * FROM keyword_clustering
# 2021-09-07 10:37:41,203 INFO sqlalchemy.engine.base.Engine ()
#      index                           Top queries  Clicks  Impressions     CTR  \
# 0        0                        adelphi living     255          765  33.33%
# 1        1                               adelphi      15          314   4.78%
# 2        2                   sil providers perth      11           98  11.22%
# 3        3    supported independent living perth       8          327   2.45%
# 4        4        disability accommodation perth       4          645   0.62%
# ..     ...                                   ...     ...          ...     ...
# 790    790            disabled living manchester       0            1      0%
# 791    791            disability insurance perth       0            1      0%
# 792    792  housing for people with disabilities       0            1      0%
# 793    793          disability support providers       0            1      0%
# 794    794               live in specialist care       0            1      0%
#
#      Position  Cluster Number                        Cluster Name
# 0        1.06               0               adelphi freedom perth
# 1       10.04               0               adelphi freedom perth
# 2        2.20               1          perth providers disability
# 3        8.10               2        independent living supported
# 4       21.36              22  accommodation disability supported
# ..        ...             ...                                 ...
# 790    134.00              -1                   perth ndis living
# 791    141.00              33          disability perth insurance
# 792    196.00              -1                   perth ndis living
# 793    199.00              20            disability support perth
# 794    276.00              -1                   perth ndis living
#
# [795 rows x 8 columns]
