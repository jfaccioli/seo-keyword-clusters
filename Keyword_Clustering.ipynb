# %% [markdown]
# # Download and import librairies

# %%
# Import Librairies
# !pip install gspread_dataframe gspread oauth2client
# !pip install gspread-pandas
# !{sys.executable} -m pip install pygsheets
from gspread_pandas import Spread, Client
from google.oauth2.service_account import Credentials
import pandas as pd
import re
import sys
import json
import gspread
import pygsheets
import csv
from gspread_dataframe import get_as_dataframe, set_with_dataframe
from oauth2client.service_account import ServiceAccountCredentials
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction import text
from sklearn.cluster import DBSCAN

# %% [markdown]
# # Import our Google Search Console data from a CSV file

# %%
# Import our Google Search Console CSV Data into a Dataframe
df = pd.read_csv('Queries.csv', delimiter=',')
df.head(20)
# Out:
#                                  Top queries  Clicks  Impressions     CTR  \
# 0                             adelphi living     289          834  34.65%
# 1                                    adelphi      15          298   5.03%
# 2                        sil providers perth      12           90  13.33%
# 3         supported independent living perth       7          323   2.17%
# 4                    adelphi living mandurah       7           30  23.33%
# 5             disability accommodation perth       3          641   0.47%
# 6                     ndis providers near me       3           45   6.67%
# 7                        sda providers perth       3           23  13.04%
# 8                   disability housing perth       2          541   0.37%
# 9                       ndis providers perth       2          258   0.78%
# 10                                  sil ndis       1          656   0.15%
# 11                        ndis housing perth       1          460   0.22%
# 12                                       sil       1          232   0.43%
# 13  disability supported accommodation perth       1          220   0.45%
# 14                                  ndis sda       1          214   0.47%
# 15               disability accommodation wa       1          193   0.52%
# 16                         ndis events perth       1          187   0.53%
# 17        disability service providers perth       1          163   0.61%
# 18             ndis short term accommodation       1          106   0.94%
# 19                        disability housing       1           56   1.79%
#
#     Position
# 0       1.07
# 1       9.97
# 2       3.26
# 3      10.77
# 4       1.03
# 5      31.52
# 6       1.00
# 7       7.48
# 8      31.37
# 9      52.90
# 10     44.26
# 11     17.18
# 12      5.32
# 13     21.80
# 14     71.16
# 15     27.95
# 16     21.29
# 17     68.01
# 18     31.03
# 19     36.61

# %% [markdown]
# ## Create a list of keywords from our GSC data

# %%
# Define a variable to hold our 'Top queries' column only
top_queries = df['Top queries']

# Create a list of keywords and populate it from our dataframe
keywords = []

for x in top_queries:
  keywords.append(x)

# Display keywords list
keywords
# Out:
# ['adelphi living',
#  'adelphi',
#  'sil providers perth',
#  'supported independent living perth',
#  'adelphi living mandurah',
#  'disability accommodation perth',
#  'ndis providers near me',
#  'sda providers perth',
#  'disability housing perth',
#  'ndis providers perth',
#  'sil ndis',
#  'ndis housing perth',
#  'sil',
#  'disability supported accommodation perth',
#  'ndis sda',
#  'disability accommodation wa',
#  'ndis events perth',
#  'disability service providers perth',
#  'ndis short term accommodation',
#  'disability housing',
#  'disability homes',
#  'adelphi living jobs',
#  'sil housing',
#  'the adelphi',
#  'sda payment',
#  'sda living',
#  'support coordinators',
#  'disability services near me',
#  'adelphi house assisted living',
#  'ndis wa providers',
#  'ndis sda application form',
#  'adelphi housing',
#  'disability support organisation',
#  'disability support services near me',
#  'independent living supplies',
#  'ndis support provider',
#  'ndis',
#  'ndis perth',
#  'sda ndis',
#  'supported independent living ndis',
#  'specialist disability accommodation perth',
#  'ndis sil',
#  'ndis supported independent living',
#  'disability accommodation',
#  'supported independent living',
#  'sil provider',
#  'assisted living perth',
#  'ndis support coordination perth',
#  'sda housing perth',
#  'sda provider',
#  'disability group homes perth',
#  'ndis provider perth',
#  'independent living wa',
#  'sda accommodation',
#  'supported accommodation perth',
#  'ndis perth wa',
#  'supported living accommodation',
#  'independent living housing',
#  'sil accommodation',
#  'sil providers',
#  'supported living',
#  'supported independent living providers',
#  'ndis events',
#  'sda house',
#  'independent living specialists',
#  'what is sda',
#  'independent living',
#  'independent living perth',
#  'sda house available',
#  'sda funding',
#  'sda living western australia',
#  'support coordinator perth',
#  'supported accommodation ndis',
#  'residential disability access perth',
#  'independent living apartments for disabled',
#  'disability accommodation services',
#  'ndis provider wa',
#  'independent living perth wa',
#  'respite accommodation',
#  'independent living western australia',
#  'disability and independent living',
#  'medium term accommodation ndis',
#  'disability rental housing perth',
#  'independent living homes',
#  'independent living services',
#  'ndis service provider perth',
#  'sda apartments',
#  'assisted living',
#  'ndis providers wa',
#  'sda perth',
#  'specialist support coordination perth',
#  'independent living near me',
#  'disability care services perth',
#  'ndis events wa',
#  'atsa independent living expo',
#  'sda houses',
#  'ndis living',
#  'disability respite accommodation',
#  'independent living solutions',
#  'ndis independent living',
#  'ndis events western australia',
#  'housing disability perth',
#  'independent living facilities near me',
#  'ndis sil rules',
#  'specialist disability housing perth',
#  'sda funding ndis',
#  'ndis assisted living',
#  'supported accommodation for people with disabilities',
#  'ndis mental health perth',
#  'independent living disabled',
#  'sda properties perth',
#  'freedom adelphi',
#  'housing for people with disabilities perth',
#  'ndis accommodation vacancies',
#  'independent living expo',
#  'perth disability service provider and participant connection expo 2021',
#  'able living',
#  'disability apartments',
#  'disability housing solutions perth',
#  'sda homes',
#  'ndis housing',
#  'disability apartments perth',
#  'disability home care perth',
#  'assisted living apartments for disabled',
#  'sil and sda',
#  'sil accomodation',
#  'ndis properties perth',
#  'sda participants',
#  'alchera living',
#  'medium term accommodation',
#  'short term accommodation perth',
#  'disability service provider perth',
#  'mental health housing wa',
#  'disability support services perth',
#  'disability housing options perth',
#  'disability short term accommodation',
#  'ndis accommodation provider',
#  'short term accommodation ndis',
#  'ndis accommodation',
#  'ndis sda properties perth',
#  'physical disability housing perth',
#  'perth disability renovation',
#  'ndis medium term accommodation',
#  'ndis respite accommodation',
#  'sda and sil',
#  'sda providers victoria',
#  'supported independent living disability',
#  'living in perth',
#  'ndis provider',
#  'sda wa',
#  'independent living center perth',
#  'ndis service providers perth',
#  'disability services perth',
#  'disabled accommodation perth',
#  'disability residential homes',
#  'sil funding ndis',
#  'ndis sil providers',
#  'ndis supported accommodation',
#  'sda categories',
#  'sda payments',
#  'sda housing ndis',
#  'atsa',
#  'ndis respite',
#  'atsa expo',
#  'sil ndis funding',
#  'adelphi apartments perth',
#  'disabled persons housing service',
#  'adelphi apartments',
#  'sda housing availability',
#  'specialist disability accommodation providers',
#  'short term accommodation disability',
#  'retirement living perth',
#  'sil sda',
#  'it provider perth',
#  'worker accommodation',
#  'medium term accommodation perth',
#  'ndis sil eligibility',
#  'content living homes',
#  'respite care perth',
#  'perth living',
#  'sda houding ndis',
#  'sil disability housing',
#  'supported accommodation',
#  'sil assessment ndis',
#  'supported independant living facility',
#  'independent living products perth wa',
#  'sda',
#  'ndis mandurah',
#  'supported disability accommodation',
#  'disability solutions for independent living',
#  'ndis joondalup',
#  'erskine accommodation',
#  'sda providers',
#  'ndis rockingham',
#  'long stay accommodation perth',
#  'ndis support perth',
#  'sil services',
#  'disability service provider and participant connection expo 2021',
#  'sda services',
#  'sda assessment',
#  'ndis services perth',
#  'home for disabled',
#  'disability services',
#  'supported independent living wa',
#  'sda contact',
#  'respite short term accommodation',
#  'supported living ndis',
#  'what are the ndis supported indepented living',
#  'adelphi hotel perth',
#  'ndis robust housing',
#  'high physical support sda',
#  'sil eligibility',
#  'long term accommodation perth',
#  'sil supported independent living',
#  'adelphi apartments echuca',
#  'aussie living homes',
#  'sda disability',
#  'long term disability accommodation services',
#  'ndis sda rules',
#  'sil perth',
#  'disabled living apartments',
#  'housing for the disabled',
#  'disability home care services',
#  'ndis service providers wa',
#  'disability service provider and participant connection expo',
#  'disability housing wa',
#  'respite accommodation ndis',
#  'national disability insurance scheme perth',
#  'perth disability services',
#  'ndis sil provider',
#  'short term accommodation',
#  'adelphi house',
#  'ndis number',
#  'adelphi perth',
#  'ndis homes',
#  'support coordinators perth',
#  'what is sda ndis',
#  'adventist senior living',
#  'ndis contact number',
#  'mental health supported accommodation perth',
#  'sda approved housing',
#  'disabled living accommodation',
#  'altum living',
#  'respite care perth wa',
#  'perth disability service provider and participant connection expo 2021, \nperth convention and exhibition centre, 11 june',
#  'medium-term accommodation',
#  'independent living disability housing',
#  'ndis bunbury',
#  'disability',
#  'ndis wa',
#  'sda assessments',
#  'perth expo',
#  'specialist disability accommodation',
#  'home modifications perth',
#  'workers accommodation',
#  'short term accomodation ndis',
#  'sda eligibility',
#  'ndis locations',
#  'short term accommodation for disabled',
#  'disability group homes',
#  'accessible accommodation perth',
#  'community living perth',
#  'ndis eligibility wa',
#  'what is sil',
#  'sil supports',
#  'ndis apartments',
#  'perth disability expo 2021',
#  'adelphi beauty',
#  'adelphi care',
#  'sda application',
#  'ndis sil and sda',
#  'supported independent living accommodation',
#  'sda housing providers',
#  'sdas',
#  'ndis sil funding',
#  'specialised disability accommodation',
#  'living in perth wa',
#  'independent living disability',
#  'independent living services for the disabled',
#  'ndis service providers',
#  'howard emery',
#  'atsa wa',
#  'what is sil ndis',
#  'ndis sda eligibility',
#  'sil logo',
#  'ndis sda funding',
#  'robust housing',
#  'ndis short term accommodation providers',
#  'disability home care',
#  'sda design categories',
#  'contact sda',
#  'get building sda',
#  'ndis short term accommodation providers melbourne',
#  'fully accessible sda',
#  'ndis air conditioning',
#  'it providers perth',
#  'retirement living wa',
#  'wheelchair accessible accommodation perth',
#  'short term apartments perth wa',
#  'disability perth',
#  'disability support perth',
#  'disability home',
#  'sil living',
#  'ndis home and living',
#  'ndis short term accomodation',
#  'sda solutions',
#  'assisted living mandurah',
#  'sda and sil ndis',
#  'robust sda',
#  'sda assessment ndis',
#  'short stay disability accommodation',
#  'sil house',
#  'perth convention centre accommodation',
#  'sda ndis rules',
#  'home and living expo',
#  'logo adelphi',
#  'adelphi group',
#  'open homes perth',
#  'adelphi insurance',
#  'respite ndis',
#  'independent builders perth',
#  'ndis housing provider',
#  'howard accommodation',
#  'ndis provider registration wa',
#  'aldephi',
#  'home and living ndis',
#  'ndis expo perth',
#  'ndis service providers near me',
#  'adelphi menu',
#  'adelphi freedom',
#  'sda approved',
#  'ndis short term accommodation rates',
#  'ndia sil',
#  'disability respite houses',
#  'ndis accommodation support',
#  'ndis expo',
#  'specialist disability accommodation providers victoria',
#  'ndis housing providers',
#  'sil ltd',
#  'sda aged care',
#  'sda access',
#  'short stay accommodation perth',
#  'mandurah apartments',
#  'disability organisations perth',
#  'it provider',
#  'independent living centre mandurah',
#  'disability living support',
#  'disabled living near me',
#  'independent support services',
#  'living',
#  'sda approved builders',
#  'ndis disability support',
#  'aldelphi',
#  'sda housing qld',
#  'ndis renovations perth',
#  'ndis support',
#  'independant living',
#  'short term disability accommodation',
#  'ndis provider near me',
#  'sda sil',
#  'sil houses',
#  'sil ndia',
#  'living expo',
#  'sda levels ndis',
#  'what does sil include',
#  'sil homes',
#  'improved living solutions',
#  'alioth independents',
#  'difference between sil and sda',
#  'medium term accommodation providers',
#  'disability services mandurah',
#  'ndis short term accommodation providers victoria',
#  'adelphi logo',
#  'ndis short term accommodation mental health',
#  'maddington accommodation',
#  's&a living',
#  'ndis wa contact',
#  'disability activities perth',
#  'disability centre',
#  'disability service',
#  'independent supported living',
#  'support independent living',
#  'ndis phone number',
#  'housing ndis',
#  'ndis home',
#  'sil accommodation ndis',
#  'wa ndis',
#  'sda approval',
#  'disability expo perth 2021',
#  'developing australian communities expo',
#  'what is ndis sil',
#  'ndis sda housing',
#  '27 adelphi road claremont',
#  'sil disability',
#  'sda robust',
#  'sda s',
#  'independent supported living and disabilities ltd',
#  'adelphi springs',
#  'sda care',
#  'independence living',
#  'mental health accommodation perth',
#  'sda home',
#  'ndis tablet',
#  'ndis short term accommodation rules',
#  'house of hoops perth',
#  'handicap assisted living',
#  'ndis supported living',
#  'independant living solutions',
#  'possibility disability services',
#  'independant living specialists',
#  'accommodation perth region',
#  'home assist wa',
#  'short term accommodation mandurah',
#  'freedom adelphi table',
#  'long term accommodation rockingham',
#  'supported disability accommodation ndis',
#  'disability housing solutions brisbane',
#  'perth funding',
#  'silsolutions',
#  'outdoor living mandurah',
#  'sil funding',
#  'independent living accommodation',
#  'cannington accommodation',
#  'intellectual disability accommodation',
#  'diability services',
#  'disability facility',
#  'disability facility near me',
#  'housing support',
#  'independent housing',
#  'independent living support',
#  'ndis conference 2021',
#  'ndis support workers near me',
#  'supported living services',
#  'disability living',
#  'ndis disability services',
#  'ndis home care',
#  'call ndis',
#  'disability support work',
#  'disability support worker',
#  'independent living facilities for disabled',
#  'sda accomodation',
#  'supported independant living',
#  'ndis supplier',
#  'ndis houses',
#  'organisation',
#  'in home support ndis',
#  'apply for sda',
#  'sda category',
#  'atsa perth',
#  'sda eligibility criteria',
#  'sda robust housing',
#  'ndis medium term accommodation providers',
#  'what is an sda',
#  'atsa 2021',
#  'living in wa',
#  'howard livings',
#  'sda guidelines',
#  'now living',
#  'perth home expo',
#  'sda western australia',
#  'independent living ndis',
#  'sda legislation',
#  'disability independent living',
#  'sda virtual room',
#  'sda apartment',
#  'avendelle assisted living',
#  'air adelphi',
#  'live in treeby',
#  'living perth',
#  'home expo perth',
#  'independent events perth',
#  'specialist disability accommodation ndis',
#  'houses for rent in mandurah',
#  'sda log in',
#  'ndis application wa',
#  'supported independent living ndis, supported independent living vacancies, \nsupported independent living sil',
#  'individualised living options',
#  'short term accomodation',
#  'adelphi consult',
#  'living houses',
#  'independent senior living',
#  'south perth short term accommodation',
#  'adelphi echuca',
#  'adelphi portal',
#  'your homes',
#  'short term rental perth',
#  'access housing mandurah',
#  'share accommodation perth',
#  'perth exhibitions',
#  'sda logo',
#  'independent living communities',
#  'apartments mandurah',
#  'independent living equipment perth',
#  'independent living facilities',
#  'perth serviced apartment deal',
#  'disability services midland',
#  'connection perth',
#  'hotels cannington',
#  'hotels rockingham',
#  'independent living home',
#  'exhibitions perth',
#  'ndis provider logo',
#  'living wa',
#  'adlephi',
#  'adlphi',
#  'disability care center',
#  'disability care facility',
#  'disability expo',
#  'disability homes near me',
#  'disability service provider',
#  'disability services wa',
#  'disability support worker agencies',
#  'disability supported accommodation',
#  'disability supported living',
#  'flexible living',
#  'indepedent living',
#  'independent disability',
#  'independent living center',
#  'independent living victoria',
#  'indpendent living',
#  'ndis aged care providers',
#  'ndis disability housing',
#  'ndis provider in perth',
#  'ndis service',
#  'organisation and',
#  'residential disability care facility',
#  'services for independent living',
#  'support housing',
#  'support living accommodation',
#  'support workers near me',
#  'supported living accommodation near me',
#  'supported living accomodation',
#  'supported living homes',
#  'wa disability services',
#  'assisted accommodation near me',
#  'independent living program for disabled',
#  'koh living',
#  'living living',
#  'livings',
#  'mta funding',
#  'ndis home care providers',
#  'ndis meaning',
#  'ndis provider"',
#  'ndis telephone number',
#  'sda housing sydney',
#  'sda loan',
#  'sda loans',
#  'sda quote',
#  'sil insurance',
#  '360 ndis',
#  'afelphi',
#  'disablity support worker',
#  'disbaility',
#  'independent living for disabled',
#  'n.d.i.s',
#  'national disability services',
#  'ndia provider',
#  'ndis call',
#  'ndis provider number',
#  'ndis provider services',
#  'ndis specialist disability accommodation design standard',
#  'ndis.',
#  'ndis?',
#  'supported indepedent living',
#  'adalphi',
#  'ndis aged care',
#  'ndis australia',
#  'ndis service provider',
#  'sda housing adelaide',
#  'accommodation for disabled adults',
#  'accommodation for people with disabilities',
#  'contact ndis',
#  'ndis home and living supports',
#  '"ndis aged care',
#  'adelphi 2021',
#  'nursing specialty',
#  'sda grant',
#  'sda housing brisbane',
#  'sda smart homes reviews',
#  'sil housing ndis',
#  'sil.',
#  'adelphi ceo',
#  'sda call',
#  'disability specialists',
#  'indepent living',
#  'what is a sda',
#  'sda application ndis',
#  'sda panel',
#  'perth disability expo',
#  'adelphi group home',
#  'atsa expo perth',
#  'disability expo perth',
#  'improved livability',
#  'ndis short term accommodation and assistance',
#  'sil sda ndis',
#  'atsa independent living expo 2021',
#  'what is an sil ndis',
#  'sda funding levels',
#  'independent living bunbury',
#  '+independent +retirement +living',
#  'clicks adelphi',
#  'sda rules',
#  'who is sil',
#  '"exceed"',
#  'homes for independent living',
#  'independent retirement living',
#  'ndia perth',
#  'sda ceo',
#  'sda high physical support',
#  'disability sil',
#  'sda pay',
#  'individual living options',
#  'what is sda funding',
#  'ndis sda fact sheet',
#  'perth short term accommodation',
#  'treeby nursing home',
#  '"houses"',
#  'share housing perth',
#  'sil support',
#  'flintwood disability services',
#  'medium stay accommodation',
#  'what is ndis wa',
#  'disability housing solutions',
#  'houses for rent in maddington',
#  'independent living mandurah',
#  'short term lease perth',
#  'assisted living disability',
#  'erskine wa',
#  'sda rules 2020',
#  'sil home',
#  'sda ndis eligibility',
#  'sda options',
#  'home living expo',
#  'shared supported accommodation disability services',
#  'best independent living communities',
#  'disability agencies perth',
#  'short term stay perth',
#  'disability care perth',
#  'independent living houses',
#  'living in mandurah',
#  'expo perth',
#  'independent community living',
#  'sda qualification',
#  'group homes perth',
#  'ndis jobs perth wa',
#  'rockingham houses',
#  'www.sil',
#  '6107 perth',
#  'house for rent in maddington',
#  'independent living australia',
#  'perth expo centre',
#  '885 albany highway',
#  'independent living centre joondalup',
#  'accommodation rockingham wa',
#  'homes west joondalup',
#  'ndis support wa',
#  'portal cannington',
#  'accommodation in rockingham wa',
#  'claremont independent',
#  'rockingham accommodation wa',
#  'who is eligible for ndis wa',
#  'access housing perth',
#  'adelphi hotels',
#  'sda resources',
#  'beauty expo perth',
#  'mandurah accommodation',
#  'perthexpo',
#  'apartments in mandurah',
#  'short term accommodation perth wa',
#  'short term accommodation subiaco',
#  'adelphi laudale',
#  'ndis sil quote',
#  'adelphi contact',
#  'best it service provider perth',
#  'exhibitions in perth',
#  'home living exhibition 2021',
#  'rockingham wa accommodation',
#  'what is a sil',
#  'adelphi care services',
#  'medium perth',
#  'shared supported accommodation',
#  'independent living centre perth',
#  'living in baldivis',
#  'ndis living assistance',
#  'participant',
#  'simple approach perth',
#  'independent living options',
#  'rockingham accommodation',
#  'short term accommodation ndis providers',
#  'abode living',
#  'accommodation in mandurah perth',
#  'hotel cannington',
#  'independent living units adelaide',
#  'sda union',
#  'supports sil',
#  'cheap serviced apartments perth',
#  'personal services perth wa',
#  'independent living solution',
#  'perth disability',
#  'dali accommodation',
#  'serviced apartments perth',
#  'accomodation mandurah',
#  'disability care wa',
#  'disabled independent living housing',
#  'hotels in rockingham',
#  'respite care in perth',
#  'serviced accommodation perth',
#  'accommodation in mandurah wa',
#  'adelphi suites',
#  'disability employment services providers perth',
#  'disability house',
#  'adelpho',
#  'bold living',
#  'disabled living manchester',
#  'disability insurance perth',
#  'specialist disability housing',
#  'disability support providers',
#  'live in specialist care']

# %% [markdown]
# # Start clustering our keywords using Machine Learning sklearn library

# %%
# Define our keyword clustering model with sklearn and TfidfVectorizer (using DBSCAN and not Kmean)
tfidf_vectorizer = TfidfVectorizer(max_df=0.2, max_features=10000,min_df=0.01,use_idf=True, ngram_range=(1,2))

# Import our keyword list for Keyword Clustering
tfidf_matrix = tfidf_vectorizer.fit_transform(keywords)

# Define settings for cluster adjustment (number and size of clusters)
ds = DBSCAN(eps=0.7, min_samples=5).fit(tfidf_matrix)
clusters = ds.labels_

# %% [markdown]
# ## Create a dataframe to hold our keyword clusters

# %%
# Create a dataframe for our clusters
cluster_df = pd.DataFrame(clusters, columns=['Cluster Number'])

# Merge our cluster df with our top queries df
result = pd.merge(cluster_df, top_queries, left_index=True, right_index=True)

# We group our keywords by cluster number and separate them with a comma
clusters_queries = result.groupby(['Cluster Number'])['Top queries'].apply(', '.join).reset_index()

# Extend Column and Row width for a better readability 
pd.set_option('max_colwidth', 400)
pd.set_option('max_rows', 100)

clusters_queries
# Out:
#     Cluster Number  \
# 0               -1
# 1                0
# 2                1
# 3                2
# 4                3
# 5                4
# 6                5
# 7                6
# 8                7
# 9                8
# 10               9
# 11              10
# 12              11
# 13              12
# 14              13
# 15              14
# 16              15
# 17              16
# 18              17
# 19              18
# 20              19
# 21              20
# 22              21
# 23              22
# 24              23
# 25              24
# 26              25
# 27              26
# 28              27
# 29              28
# 30              29
# 31              30
# 32              31
# 33              32
# 34              33
# 35              34
# 36              35
# 37              36
# 38              37
# 39              38
# 40              39
# 41              40
# 42              41
# 43              42
# 44              43
# 45              44
# 46              45
# 47              46
#
#                                                                                                                                                                                                                                                                                                                                                                                                         Top queries
# 0   sil providers perth, disability service providers perth, sil housing, adelphi house assisted living, adelphi housing, ndis support provider, sda accommodation, sil providers, sda house, sda house available, independent living homes, independent living services, sda perth, specialist support coordination perth, independent living solutions, housing disability perth, independent living disabled,...
# 1   adelphi living, adelphi, adelphi living jobs, the adelphi, freedom adelphi, adelphi hotel perth, adelphi perth, adelphi beauty, logo adelphi, adelphi group, adelphi insurance, adelphi menu, adelphi freedom, adelphi logo, 27 adelphi road claremont, adelphi springs, freedom adelphi table, air adelphi, adelphi consult, adelphi echuca, adelphi portal, adelphi ceo, clicks adelphi, adelphi hotels, a...
# 2   supported independent living perth, supported independent living ndis, ndis supported independent living, supported independent living, supported independent living providers, supported independent living disability, supported independent living wa, sil supported independent living, supported independent living accommodation, supported independent living ndis, supported independent living vaca...
# 3                                                ndis providers near me, disability services near me, disability support services near me, independent living near me, independent living facilities near me, ndis service providers near me, disabled living near me, disability facility near me, ndis support workers near me, disability homes near me, support workers near me, assisted accommodation near me
# 36                                                                                                     disability services perth, disability services, perth disability services, disability services mandurah, possibility disability services, ndis disability services, disability services midland, disability services wa, wa disability services, national disability services, flintwood disability services
# 37                                                                                                                   disabled accommodation perth, long stay accommodation perth, accessible accommodation perth, wheelchair accessible accommodation perth, short stay accommodation perth, mental health accommodation perth, accommodation perth region, share accommodation perth, serviced accommodation perth
# 38                                                                                                                                                                                                                                                                          adelphi living mandurah, ndis mandurah, outdoor living mandurah, access housing mandurah, mandurah accommodation, accomodation mandurah
# 39                                                                                                                                                                                           independent living apartments for disabled, home for disabled, independent living facilities for disabled, independent living program for disabled, independent living for disabled, accommodation for disabled adults
# 40                                                                                                                                                                                                                                                                                            ndis wa providers, ndis providers wa, ndis service providers perth, ndis service providers wa, ndis service providers
# 41                                                                                                                                                                                                                                                                                                                    disability, disability centre, disability facility, disability living, disability specialists
# 42                                                                   perth expo, home modifications perth, ndis expo perth, ndis expo, living expo, ndis home, developing australian communities expo, sda home, perth home expo, home expo perth, disability expo, perth disability expo, disability expo perth, treeby nursing home, sil home, home living expo, expo perth, perth expo centre, beauty expo perth
# 43                                                                                                                                                                                                                                                                                                                  ndis home and living, home and living expo, home and living ndis, ndis home and living supports
# 44                                                                                                                                                                                                                                                                                                           sil provider, sda provider, ndis accommodation provider, it provider perth, it provider, ndia provider
# 45                                                                                                                                                                                                                                                                                                                                                     sda houses, sil houses, ndis houses, living houses, "houses"
# 46                                                                                                                                                                                                                                                                                                              living in perth, living in wa, live in treeby, sda log in, exhibitions in perth, living in baldivis
# 47                                                                                                                                                                                                        ndis rockingham, hotels rockingham, accommodation rockingham wa, accommodation in rockingham wa, rockingham accommodation wa, rockingham wa accommodation, rockingham accommodation, hotels in rockingham

# %% [markdown]
# ## Use the same ML model on each cluster so we can name our clusters automatically

# %%
# Create an empty list to store our cluster names
cluster_name = []

# Use Iterrows and tfIdVectorizer to get all words and their TF-IDF Score per cluster
for index, row in clusters_queries.iterrows():
    
    queries = row['Top queries']
    queries = [queries]

    # Add a stop_words function to drop irrelevant words (ex: “a”, “the”, “is”, “are”, "and" etc...)
    my_stop_words = text.ENGLISH_STOP_WORDS

    # Run tfIdfVectorizer for each cluster
    tfIdfVectorizer=TfidfVectorizer(use_idf=True, stop_words=my_stop_words)
    tfIdf = tfIdfVectorizer.fit_transform(queries)
    query_score_cluster = pd.DataFrame(tfIdf[0].T.todense(), index=tfIdfVectorizer.get_feature_names(), columns=["TF-IDF Score"])
    query_score_cluster = query_score_cluster.sort_values('TF-IDF Score', ascending=False)

    # Get the top 3 queries (selected by highest scores) per cluster and get them into lists, clean words of commas and ''
    top_three_queries = query_score_cluster.index[:3]
    top_three_queries_list = top_three_queries.values.tolist()
    top_three_queries_list = str(top_three_queries_list).replace(',', '')
    top_three_queries_list = str(top_three_queries_list).replace('[','').replace(']','')
    top_three_queries_list = str(top_three_queries_list).replace("'","")

    # Append our top 3 queries to our cluster_name list
    cluster_name.append(top_three_queries_list)
    
    # Create a Cluster Name dataframe    
    cluster_name_df = pd.DataFrame({'Cluster Name': cluster_name})

cluster_name_df
# Out:
#                            Cluster Name
# 0                     living perth ndis
# 1                 adelphi freedom perth
# 2          independent living supported
# 3                near disability living
# 4                   providers perth sda
# 5              housing disability perth
# 6                          sil ndis sda
# 7    accommodation supported disability
# 8                  ndis sda application
# 9                     perth ndis living
# 10             term short accommodation
# 11               homes disability group
# 12                 sda ndis eligibility
# 13                   support ndis perth
# 14             disability support perth
# 15             independent living perth
# 16                   living ndis number
# 17  accommodation disability specialist
# 18                     ndis sil funding
# 19    accommodation disability services
# 20            assisted living avendelle
# 21                  ndis provider perth
# 22                      perth wa living
# 23         living supported independent
# 24                         ndis sda sil
# 25           disability perth insurance
# 26           respite accommodation ndis
# 27          provider service disability
# 28                       wa ndis living
# 29                expo atsa independent
# 30        accommodation ndis cannington
# 31                  housing ndis robust
# 32             apartments perth adelphi
# 33                 care disability home
# 34                         sda sil ndis
# 35            accommodation medium term
# 36            disability services perth
# 37       accommodation perth accessible
# 38               mandurah living access
# 39          disabled independent living
# 40               ndis providers service
# 41           disability centre facility
# 42                      expo perth home
# 43                     home living ndis
# 44          provider accommodation ndia
# 45                   houses living ndis
# 46                living perth baldivis
# 47          rockingham accommodation wa

# %% [markdown]
# # Merge our dataframes so we can see all of our keywords grouped into different clusters and their names automatically generated. We can make sure it is matching properly

# %%
# Merge cluster_name_df with clusters_queries so we can have them matching and double check the cluster names match with our queries
clusters = pd.merge(cluster_name_df, clusters_queries, left_index=True, right_index=True)
clusters
# Out:
#                            Cluster Name  Cluster Number  \
# 0                     living perth ndis              -1
# 1                 adelphi freedom perth               0
# 2          independent living supported               1
# 3                near disability living               2
# 4                   providers perth sda               3
# 5              housing disability perth               4
# 6                          sil ndis sda               5
# 7    accommodation supported disability               6
# 8                  ndis sda application               7
# 9                     perth ndis living               8
# 10             term short accommodation               9
# 11               homes disability group              10
# 12                 sda ndis eligibility              11
# 13                   support ndis perth              12
# 14             disability support perth              13
# 15             independent living perth              14
# 16                   living ndis number              15
# 17  accommodation disability specialist              16
# 18                     ndis sil funding              17
# 19    accommodation disability services              18
# 20            assisted living avendelle              19
# 21                  ndis provider perth              20
# 22                      perth wa living              21
# 23         living supported independent              22
# 24                         ndis sda sil              23
# 25           disability perth insurance              24
# 26           respite accommodation ndis              25
# 27          provider service disability              26
# 28                       wa ndis living              27
# 29                expo atsa independent              28
# 30        accommodation ndis cannington              29
# 31                  housing ndis robust              30
# 32             apartments perth adelphi              31
# 33                 care disability home              32
# 34                         sda sil ndis              33
# 35            accommodation medium term              34
# 36            disability services perth              35
# 37       accommodation perth accessible              36
# 38               mandurah living access              37
# 39          disabled independent living              38
# 40               ndis providers service              39
# 41           disability centre facility              40
# 42                      expo perth home              41
# 43                     home living ndis              42
# 44          provider accommodation ndia              43
# 45                   houses living ndis              44
# 46                living perth baldivis              45
# 47          rockingham accommodation wa              46
#
# 29                                                                                                                                                                                                                                                                                             atsa independent living expo, independent living expo, atsa expo, atsa expo perth, atsa independent living expo 2021
# 30                                                                                                                                                                                               ndis accommodation vacancies, ndis accommodation, worker accommodation, erskine accommodation, workers accommodation, howard accommodation, maddington accommodation, cannington accommodation, dali accommodation
# 31                                                                                                                                                                                                                                                                                                        ndis housing, ndis robust housing, sda approved housing, robust housing, housing ndis, sda robust housing
# 32                                                                                                                                                                                         sda apartments, disability apartments, disability apartments perth, adelphi apartments perth, adelphi apartments, adelphi apartments echuca, ndis apartments, cheap serviced apartments perth, serviced apartments perth
# 33                                          disability care services perth, disability home care perth, disability home care services, disability home care, disability home, sda aged care, sda care, ndis home care, disability care center, disability care facility, residential disability care facility, ndis home care providers, ndis aged care, "ndis aged care, disability care perth, disability care wa
# 34                                                                                                                                                                                                                                                                                                                     sil and sda, sda and sil, ndis sil and sda, sda and sil ndis, difference between sil and sda
# 35                                                                                                                                                                             medium term accommodation ndis, medium term accommodation, ndis medium term accommodation, medium term accommodation perth, medium-term accommodation, medium term accommodation providers, ndis medium term accommodation providers
# 36                                                                                                     disability services perth, disability services, perth disability services, disability services mandurah, possibility disability services, ndis disability services, disability services midland, disability services wa, wa disability services, national disability services, flintwood disability services
# 37                                                                                                                   disabled accommodation perth, long stay accommodation perth, accessible accommodation perth, wheelchair accessible accommodation perth, short stay accommodation perth, mental health accommodation perth, accommodation perth region, share accommodation perth, serviced accommodation perth
# 38                                                                                                                                                                                                                                                                          adelphi living mandurah, ndis mandurah, outdoor living mandurah, access housing mandurah, mandurah accommodation, accomodation mandurah
# 39                                                                                                                                                                                           independent living apartments for disabled, home for disabled, independent living facilities for disabled, independent living program for disabled, independent living for disabled, accommodation for disabled adults
# 40                                                                                                                                                                                                                                                                                            ndis wa providers, ndis providers wa, ndis service providers perth, ndis service providers wa, ndis service providers
# 41                                                                                                                                                                                                                                                                                                                    disability, disability centre, disability facility, disability living, disability specialists
# 42                                                                   perth expo, home modifications perth, ndis expo perth, ndis expo, living expo, ndis home, developing australian communities expo, sda home, perth home expo, home expo perth, disability expo, perth disability expo, disability expo perth, treeby nursing home, sil home, home living expo, expo perth, perth expo centre, beauty expo perth
# 43                                                                                                                                                                                                                                                                                                                  ndis home and living, home and living expo, home and living ndis, ndis home and living supports
# 44                                                                                                                                                                                                                                                                                                           sil provider, sda provider, ndis accommodation provider, it provider perth, it provider, ndia provider
# 45                                                                                                                                                                                                                                                                                                                                                     sda houses, sil houses, ndis houses, living houses, "houses"
# 46                                                                                                                                                                                                                                                                                                              living in perth, living in wa, live in treeby, sda log in, exhibitions in perth, living in baldivis
# 47                                                                                                                                                                                                        ndis rockingham, hotels rockingham, accommodation rockingham wa, accommodation in rockingham wa, rockingham accommodation wa, rockingham wa accommodation, rockingham accommodation, hotels in rockingham

# %% [markdown]
# ## We only retain our Cluster names and numbers together

# %%
# splited_clusters = pd.concat([pd.Series(row['Cluster Name'], row['Top queries'].split(','))              
#                     for _, row in clusters.iterrows()]).reset_index()
cluster_name_nb = clusters[["Cluster Name", "Cluster Number"]]
cluster_name_nb.head()
# Out:
#                    Cluster Name  Cluster Number
# 0             living perth ndis              -1
# 1         adelphi freedom perth               0
# 2  independent living supported               1
# 3        near disability living               2
# 4           providers perth sda               3

# %%
# Merge it with our machine learning results
clusters_queries = pd.merge(result, cluster_name_nb, how="inner", on="Cluster Number")
clusters_queries.head()
# Out:
#    Cluster Number          Top queries           Cluster Name
# 0               0       adelphi living  adelphi freedom perth
# 1               0              adelphi  adelphi freedom perth
# 2               0  adelphi living jobs  adelphi freedom perth
# 3               0          the adelphi  adelphi freedom perth
# 4               0      freedom adelphi  adelphi freedom perth

# %%
# Merge it with the original dataset to get the matching query performances
final_df = pd.merge(df, clusters_queries, how="inner", on="Top queries")
final_df
# Out:
#                             Top queries  Clicks  Impressions     CTR  \
# 0                        adelphi living     289          834  34.65%
# 1                               adelphi      15          298   5.03%
# 2                   sil providers perth      12           90  13.33%
# 3    supported independent living perth       7          323   2.17%
# 4               adelphi living mandurah       7           30  23.33%
# ..                                  ...     ...          ...     ...
# 713          disabled living manchester       0            1      0%
# 714          disability insurance perth       0            1      0%
# 715       specialist disability housing       0            1      0%
# 716        disability support providers       0            1      0%
# 717             live in specialist care       0            1      0%
#
#      Position  Cluster Number                  Cluster Name
# 0        1.07               0         adelphi freedom perth
# 1        9.97               0         adelphi freedom perth
# 2        3.26              -1             living perth ndis
# 3       10.77               1  independent living supported
# 4        1.03              37        mandurah living access
# ..        ...             ...                           ...
# 713    134.00              -1             living perth ndis
# 714    141.00              24    disability perth insurance
# 715    149.00              -1             living perth ndis
# 716    199.00              13      disability support perth
# 717    276.00              -1             living perth ndis
#
# [718 rows x 7 columns]

# %% [markdown]
# ### We now have a complete dataframe with our queries, performances and corresponding cluster names.
#
# ### It means we can now perform data analysis per cluster, which can be useful especially if you have a lot of queries

# %% [markdown]
# ## Export our dataframe to a Google Spreadsheet (previously created) so it can be read dynamically with Tableau and Google Data Studio

# %%
# Use of gspread to connect our Google Spreadsheet to our final dataframe
scope = ['https://www.googleapis.com/auth/spreadsheets',
        'https://www.googleapis.com/auth/drive']

# Load credentials (not on the github / heroku folder, has to be replaced manually for safety purposes)
creds = Credentials.from_service_account_file("default.json", scopes=scope)
client = gspread.authorize(creds)

# Loading a Google Spreadsheet created before
google_sh = client.open("keyword_clustering")

# Selecting the sheet
sheet1 = google_sh.get_worksheet(0)

# Clearing output
sheet1.clear()

# Send our pandas dataframe to the google spreadsheet (you will be able to load it from Tableau and Google Data Studio)
df_google = set_with_dataframe(sheet1, final_df)

# %%
# Read our Google Spreadsheet to confirm the data has been correctly exported ('Unnamed' are the empty cells)
df_google = get_as_dataframe(sheet1)
df_google.head(20)
# Out:
#                                  Top queries  Clicks  Impressions     CTR  \
# 0                             adelphi living   289.0        834.0  0.3465
# 1                                    adelphi    15.0        298.0  0.0503
# 2                        sil providers perth    12.0         90.0  0.1333
# 3         supported independent living perth     7.0        323.0  0.0217
# 4                    adelphi living mandurah     7.0         30.0  0.2333
# 5             disability accommodation perth     3.0        641.0  0.0047
# 6                     ndis providers near me     3.0         45.0  0.0667
# 7                        sda providers perth     3.0         23.0  0.1304
# 8                   disability housing perth     2.0        541.0  0.0037
# 9                       ndis providers perth     2.0        258.0  0.0078
# 10                                  sil ndis     1.0        656.0  0.0015
# 11                        ndis housing perth     1.0        460.0  0.0022
# 12                                       sil     1.0        232.0  0.0043
# 13  disability supported accommodation perth     1.0        220.0  0.0045
# 14                                  ndis sda     1.0        214.0  0.0047
# 15               disability accommodation wa     1.0        193.0  0.0052
# 16                         ndis events perth     1.0        187.0  0.0053
# 17        disability service providers perth     1.0        163.0  0.0061
# 18             ndis short term accommodation     1.0        106.0  0.0094
# 19                        disability housing     1.0         56.0  0.0179
#
#     Position  Cluster Number                        Cluster Name  Unnamed: 7  \
# 0       1.07             0.0               adelphi freedom perth         NaN
# 1       9.97             0.0               adelphi freedom perth         NaN
# 2       3.26            -1.0                   living perth ndis         NaN
# 3      10.77             1.0        independent living supported         NaN
# 4       1.03            37.0              mandurah living access         NaN
# 5      31.52            18.0   accommodation disability services         NaN
# 6       1.00             2.0              near disability living         NaN
# 7       7.48             3.0                 providers perth sda         NaN
# 8      31.37             4.0            housing disability perth         NaN
# 9      52.90             3.0                 providers perth sda         NaN
# 10     44.26             5.0                        sil ndis sda         NaN
# 11     17.18             4.0            housing disability perth         NaN
# 12      5.32             5.0                        sil ndis sda         NaN
# 13     21.80             6.0  accommodation supported disability         NaN
# 14     71.16             7.0                ndis sda application         NaN
# 15     27.95            18.0   accommodation disability services         NaN
# 16     21.29             8.0                   perth ndis living         NaN
# 17     68.01            -1.0                   living perth ndis         NaN
# 18     31.03             9.0            term short accommodation         NaN
# 19     36.61             4.0            housing disability perth         NaN
#
#     Unnamed: 8  Unnamed: 9  ...  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# 0          NaN         NaN  ...          NaN          NaN          NaN
# 1          NaN         NaN  ...          NaN          NaN          NaN
# 2          NaN         NaN  ...          NaN          NaN          NaN
# 3          NaN         NaN  ...          NaN          NaN          NaN
# 4          NaN         NaN  ...          NaN          NaN          NaN
# 5          NaN         NaN  ...          NaN          NaN          NaN
# 6          NaN         NaN  ...          NaN          NaN          NaN
# 7          NaN         NaN  ...          NaN          NaN          NaN
# 8          NaN         NaN  ...          NaN          NaN          NaN
# 9          NaN         NaN  ...          NaN          NaN          NaN
# 10         NaN         NaN  ...          NaN          NaN          NaN
# 11         NaN         NaN  ...          NaN          NaN          NaN
# 12         NaN         NaN  ...          NaN          NaN          NaN
# 13         NaN         NaN  ...          NaN          NaN          NaN
# 14         NaN         NaN  ...          NaN          NaN          NaN
# 15         NaN         NaN  ...          NaN          NaN          NaN
# 16         NaN         NaN  ...          NaN          NaN          NaN
# 17         NaN         NaN  ...          NaN          NaN          NaN
# 18         NaN         NaN  ...          NaN          NaN          NaN
# 19         NaN         NaN  ...          NaN          NaN          NaN
#
#     Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN          NaN
# 7           NaN          NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN          NaN
# 9           NaN          NaN          NaN          NaN          NaN
# 10          NaN          NaN          NaN          NaN          NaN
# 11          NaN          NaN          NaN          NaN          NaN
# 12          NaN          NaN          NaN          NaN          NaN
# 13          NaN          NaN          NaN          NaN          NaN
# 14          NaN          NaN          NaN          NaN          NaN
# 15          NaN          NaN          NaN          NaN          NaN
# 16          NaN          NaN          NaN          NaN          NaN
# 17          NaN          NaN          NaN          NaN          NaN
# 18          NaN          NaN          NaN          NaN          NaN
# 19          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 24  Unnamed: 25
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4           NaN          NaN
# 5           NaN          NaN
# 6           NaN          NaN
# 7           NaN          NaN
# 8           NaN          NaN
# 9           NaN          NaN
# 10          NaN          NaN
# 11          NaN          NaN
# 12          NaN          NaN
# 13          NaN          NaN
# 14          NaN          NaN
# 15          NaN          NaN
# 16          NaN          NaN
# 17          NaN          NaN
# 18          NaN          NaN
# 19          NaN          NaN
#
# [20 rows x 26 columns]

# %% [markdown]
# ## Export our final_df Dataframe to sqlite for further purposes (ex: load JSON URL data with Plotly or D3)

# %%
# SQL Alchemy
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
# Create connection
engine = create_engine('sqlite:///keyword_clustering.sqlite', echo=True)
conn = engine.connect()
# Out:
# 2021-08-25 19:34:47,147 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-08-25 19:34:47,152 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:34:47,156 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-08-25 19:34:47,158 INFO sqlalchemy.engine.base.Engine ()

# %%
# Reflect an existing database into a new model
Base = automap_base()
Base.prepare(engine, reflect=True)
# Out:
# 2021-08-25 19:38:19,689 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-08-25 19:38:19,691 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:19,693 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("keyword_clustering")
# 2021-08-25 19:38:19,694 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:19,697 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'keyword_clustering' AND type = 'table'
# 2021-08-25 19:38:19,698 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:19,700 INFO sqlalchemy.engine.base.Engine PRAGMA main.foreign_key_list("keyword_clustering")
# 2021-08-25 19:38:19,701 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:19,702 INFO sqlalchemy.engine.base.Engine PRAGMA temp.foreign_key_list("keyword_clustering")
# 2021-08-25 19:38:19,703 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:19,705 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'keyword_clustering' AND type = 'table'
# 2021-08-25 19:38:19,705 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:19,707 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("keyword_clustering")
# 2021-08-25 19:38:19,707 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:19,709 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_info("ix_keyword_clustering_index")
# 2021-08-25 19:38:19,709 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:19,711 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("keyword_clustering")
# 2021-08-25 19:38:19,712 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:19,713 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_info("ix_keyword_clustering_index")
# 2021-08-25 19:38:19,714 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:19,715 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'keyword_clustering' AND type = 'table'
# 2021-08-25 19:38:19,716 INFO sqlalchemy.engine.base.Engine ()

# %%
# Export our dataframe to SQL and replace the data if the table is already there
final_df.to_sql("keyword_clustering", conn, if_exists="replace")
# Out:
# 2021-08-25 19:38:21,266 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("keyword_clustering")
# 2021-08-25 19:38:21,267 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:21,269 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("keyword_clustering")
# 2021-08-25 19:38:21,271 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:21,272 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-08-25 19:38:21,273 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:21,275 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("keyword_clustering")
# 2021-08-25 19:38:21,276 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:21,279 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'keyword_clustering' AND type = 'table'
# 2021-08-25 19:38:21,280 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:21,282 INFO sqlalchemy.engine.base.Engine PRAGMA main.foreign_key_list("keyword_clustering")
# 2021-08-25 19:38:21,283 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:21,285 INFO sqlalchemy.engine.base.Engine PRAGMA temp.foreign_key_list("keyword_clustering")
# 2021-08-25 19:38:21,285 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:21,286 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'keyword_clustering' AND type = 'table'
# 2021-08-25 19:38:21,287 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:21,289 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("keyword_clustering")
# 2021-08-25 19:38:21,291 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:21,292 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_info("ix_keyword_clustering_index")
# 2021-08-25 19:38:21,293 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:21,295 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("keyword_clustering")
# 2021-08-25 19:38:21,296 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:21,298 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_info("ix_keyword_clustering_index")
# 2021-08-25 19:38:21,299 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:21,300 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'keyword_clustering' AND type = 'table'
# 2021-08-25 19:38:21,301 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:21,302 INFO sqlalchemy.engine.base.Engine
# DROP TABLE keyword_clustering
# 2021-08-25 19:38:21,303 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:21,332 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-08-25 19:38:21,335 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE keyword_clustering (
# 	"index" BIGINT,
# 	"Top queries" TEXT,
# 	"Clicks" BIGINT,
# 	"Impressions" BIGINT,
# 	"CTR" TEXT,
# 	"Position" FLOAT,
# 	"Cluster Number" BIGINT,
# 	"Cluster Name" TEXT
# )
#
#
# 2021-08-25 19:38:21,335 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:21,362 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-08-25 19:38:21,364 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_keyword_clustering_index ON keyword_clustering ("index")
# 2021-08-25 19:38:21,364 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:21,393 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-08-25 19:38:21,396 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-08-25 19:38:21,404 INFO sqlalchemy.engine.base.Engine INSERT INTO keyword_clustering ("index", "Top queries", "Clicks", "Impressions", "CTR", "Position", "Cluster Number", "Cluster Name") VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2021-08-25 19:38:21,405 INFO sqlalchemy.engine.base.Engine ((0, 'adelphi living', 289, 834, '34.65%', 1.07, 0, 'adelphi freedom perth'), (1, 'adelphi', 15, 298, '5.03%', 9.97, 0, 'adelphi freedom perth'), (2, 'sil providers perth', 12, 90, '13.33%', 3.26, -1, 'living perth ndis'), (3, 'supported independent living perth', 7, 323, '2.17%', 10.77, 1, 'independent living supported'), (4, 'adelphi living mandurah', 7, 30, '23.33%', 1.03, 37, 'mandurah living access'), (5, 'disability accommodation perth', 3, 641, '0.47%', 31.52, 18, 'accommodation disability services'), (6, 'ndis providers near me', 3, 45, '6.67%', 1.0, 2, 'near disability living'), (7, 'sda providers perth', 3, 23, '13.04%', 7.48, 3, 'providers perth sda')  ... displaying 10 of 718 total bound parameter sets ...  (716, 'disability support providers', 0, 1, '0%', 199.0, 13, 'disability support perth'), (717, 'live in specialist care', 0, 1, '0%', 276.0, -1, 'living perth ndis'))
# 2021-08-25 19:38:21,414 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
# Reflect Database into ORM classes
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# 2021-08-25 19:38:23,866 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-08-25 19:38:23,867 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:23,869 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("keyword_clustering")
# 2021-08-25 19:38:23,870 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:23,872 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'keyword_clustering' AND type = 'table'
# 2021-08-25 19:38:23,874 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:23,875 INFO sqlalchemy.engine.base.Engine PRAGMA main.foreign_key_list("keyword_clustering")
# 2021-08-25 19:38:23,877 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:23,878 INFO sqlalchemy.engine.base.Engine PRAGMA temp.foreign_key_list("keyword_clustering")
# 2021-08-25 19:38:23,878 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:23,879 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'keyword_clustering' AND type = 'table'
# 2021-08-25 19:38:23,880 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:23,881 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("keyword_clustering")
# 2021-08-25 19:38:23,882 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:23,884 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_info("ix_keyword_clustering_index")
# 2021-08-25 19:38:23,885 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:23,887 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("keyword_clustering")
# 2021-08-25 19:38:23,888 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:23,891 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_info("ix_keyword_clustering_index")
# 2021-08-25 19:38:23,892 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:23,893 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'keyword_clustering' AND type = 'table'
# 2021-08-25 19:38:23,894 INFO sqlalchemy.engine.base.Engine ()
# []

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
# Use `engine.execute` to select and display the first 10 rows from the station table
engine.execute('SELECT * FROM keyword_clustering LIMIT 5').fetchall()
# Out:
# 2021-08-25 19:38:27,149 INFO sqlalchemy.engine.base.Engine SELECT * FROM keyword_clustering LIMIT 5
# 2021-08-25 19:38:27,150 INFO sqlalchemy.engine.base.Engine ()
# [(0, 'adelphi living', 289, 834, '34.65%', 1.07, 0, 'adelphi freedom perth'),
#  (1, 'adelphi', 15, 298, '5.03%', 9.97, 0, 'adelphi freedom perth'),
#  (2, 'sil providers perth', 12, 90, '13.33%', 3.26, -1, 'living perth ndis'),
#  (3, 'supported independent living perth', 7, 323, '2.17%', 10.77, 1, 'independent living supported'),
#  (4, 'adelphi living mandurah', 7, 30, '23.33%', 1.03, 37, 'mandurah living access')]

# %%
# Query keyword_clustering in the the Database
data = pd.read_sql("SELECT * FROM keyword_clustering", conn)
data
# Out:
# 2021-08-25 19:38:28,769 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("SELECT * FROM keyword_clustering")
# 2021-08-25 19:38:28,770 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:28,772 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("SELECT * FROM keyword_clustering")
# 2021-08-25 19:38:28,772 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-25 19:38:28,774 INFO sqlalchemy.engine.base.Engine SELECT * FROM keyword_clustering
# 2021-08-25 19:38:28,775 INFO sqlalchemy.engine.base.Engine ()
#      index                         Top queries  Clicks  Impressions     CTR  \
# 0        0                      adelphi living     289          834  34.65%
# 1        1                             adelphi      15          298   5.03%
# 2        2                 sil providers perth      12           90  13.33%
# 3        3  supported independent living perth       7          323   2.17%
# 4        4             adelphi living mandurah       7           30  23.33%
# ..     ...                                 ...     ...          ...     ...
# 713    713          disabled living manchester       0            1      0%
# 714    714          disability insurance perth       0            1      0%
# 715    715       specialist disability housing       0            1      0%
# 716    716        disability support providers       0            1      0%
# 717    717             live in specialist care       0            1      0%
#
#      Position  Cluster Number                  Cluster Name
# 0        1.07               0         adelphi freedom perth
# 1        9.97               0         adelphi freedom perth
# 2        3.26              -1             living perth ndis
# 3       10.77               1  independent living supported
# 4        1.03              37        mandurah living access
# ..        ...             ...                           ...
# 713    134.00              -1             living perth ndis
# 714    141.00              24    disability perth insurance
# 715    149.00              -1             living perth ndis
# 716    199.00              13      disability support perth
# 717    276.00              -1             living perth ndis
#
# [718 rows x 8 columns]
